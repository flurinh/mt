# %%
from processor import *
from analysis import *
import numpy as np
from scipy.spatial.distance import cdist, pdist
import seaborn as sns
from matplotlib import rcParams
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
p = CifProcessor()
p.read_pkl_metainfo()
p.read_pkl(mode='rg', folder='data/processed/')
# Out:
# Reading files with generic numbers on receptors and gproteins.

# %%
ATOM_LIST=['CA']

# %%
f_act = p.filter_dfl_via_table(State='Active', Cl='Rhodopsin', gprotein=True)
f_act = f_act[f_act['Method']=='cryo-EM']

# %%
p.apply_filter(f_act)

# %%
p.dfl_list[33]
# Out:
# '7CKX'

# %%
eg = 47

# %%
df_r = section_filter(p.dfl[eg].copy(), chain='r', start=3.40, end=3.52)

# %%
df_g = section_filter(p.dfl[eg].copy(), chain='g', gprot_region='HN', start=30, end=50)

# %%
p.table['angle'] = 0.000
for pdb in p.dfl_list:#p.dfl_list
    i = p.dfl_list.index(pdb)
    if pdb != p.dfl[i]['PDB'].iloc[0]:
        print("dfl list and df in dfl at corr index do not match!")
        
    df_r = section_filter(p.dfl[i].copy(), chain='r', start=8.50, end=9)
    df_g = section_filter(p.dfl[i].copy(), chain='g', gprot_region='HN', start=33, end=53)
    
    xyz_r, mean_r = get_coords(df_r, False)
    xyz_g, mean_g = get_coords(df_g, False)
    
    if (xyz_r.shape[0]>4) & (xyz_g.shape[0]>4):
        v_r = get_helix(xyz_r-np.asarray(mean_r))
        v_g = get_helix(xyz_g-np.asarray(mean_g))
        vector_r = v_r * np.mgrid[-10:10:2j][:, np.newaxis]
        vector_g = v_g * np.mgrid[-10:10:2j][:, np.newaxis]

        angle_ = angle(v_r, v_g)
        if angle_ < 90:
            angle_ = 180 - angle_
        print(pdb, angle_)
        p.table.loc[p.table['PDB']==pdb, 'angle'] = angle_
# Out:
# 6CMO 100.67667188158818
# 6D9H 117.1540930399338
# 6KPF 127.08287206581615
# 6KPG 117.11737271505034
# 6LFM 137.24433081388398
# 6LFO 134.82421445337116
# 6N4B 114.92906979877633
# 6NI3 132.2421027688208
# 6OIK 93.96798635264149
# 6OMM 145.26052836004217
# 6OS9 116.20641396841395
# 6OSA 115.34310471871656
# 6OY9 114.29147453482318
# 6OYA 106.14438655640676
# 6PT0 117.11270571387797
# 6QNO 106.28246634066238
# 7BW0 117.64083082417105
# 7BZ2 96.55216493322142
# 7CFM 109.93885914375427
# 7CFN 123.58648352835185
# 7CKW 147.30588652365753
# 7CKX 145.74736907610284
# 7CKY 146.32455751407664
# 7CKZ 147.23813770272864
# 7CMU 124.28051482167882
# 7CMV 122.5371695102746
# 7CRH 145.8232298932061
# 7DHI 99.49796923146607
# 7DHR 100.39983452734194
# 7E2X 145.51905910808847
# 7E2Y 146.6021758702442
# 7E2Z 143.09190967513058
# 7E32 135.64147778821774
# 7E33 143.08882138295937
# 7JJO 151.778962480955
# 7JV5 141.58570929268308
# 7JVP 137.34827904216434
# 7JVR 124.32037015261346
# 7L0P 142.02250836180113
# 7L0Q 142.02250836180113
# 7L0R 91.88062020457208
# 7L0S 91.87977379864195

# %%
p.table[p.table['PDB']=='5UIW']
# Out:
# Empty DataFrame
# Columns: [uniprot(gene), receptor family, Cl., Species, Method, PDB, Resolution, Preferred Chain, State, Degree active %, Family, Subtype, Function, angle]
# Index: []

# %%
p.table[p.table['angle']>0].groupby('Family').mean()['angle']
# Out:
# Family
# Gi/o    122.834244
# Gs      129.534025
# Name: angle, dtype: float64

# %%
small = p.table[['PDB', 'uniprot(gene)', 'Family', 'angle']].copy()

# %%
small[(p.table['angle']>0)&(small['Family']=='Gi/o')].reset_index(drop=True).sort_values('uniprot(gene)')#.to_csv('gio_angle_tm3_h5.csv')
# Out:
#      PDB uniprot(gene) Family       angle
# 6   7E2Z         5HT1A   Gi/o  143.091910
# 8   7E2X         5HT1A   Gi/o  145.519059
# 10  7E2Y         5HT1A   Gi/o  146.602176
# 9   7E32         5HT1D   Gi/o  135.641478
# 7   7E33         5HT1E   Gi/o  143.088821
# 15  6D9H          AA1R   Gi/o  117.154093
# 5   6OIK          ACM2   Gi/o   93.967986
# 17  6KPG          CNR1   Gi/o  117.117373
# 14  6N4B          CNR1   Gi/o  114.929070
# 16  6KPF          CNR2   Gi/o  127.082872
# 11  6PT0          CNR2   Gi/o  117.112706
# 0   6LFO         CXCR2   Gi/o  134.824214
# 1   6LFM         CXCR2   Gi/o  137.244331
# 4   7JVR          DRD2   Gi/o  124.320370
# 13  7CMV          DRD3   Gi/o  122.537170
# 12  7CMU          DRD3   Gi/o  124.280515
# 18  6OMM          FPR2   Gi/o  145.260528
# 3   6OS9          NTR1   Gi/o  116.206414
# 2   6OSA          NTR1   Gi/o  115.343105
# 23  7L0P          NTR1   Gi/o  142.022508
# 24  7L0R          NTR1   Gi/o   91.880620
# 25  7L0S          NTR1   Gi/o   91.879774
# 26  7L0Q          NTR1   Gi/o  142.022508
# 19  6OY9          OPSD   Gi/o  114.291475
# 20  6OYA          OPSD   Gi/o  106.144387
# 21  6CMO          OPSD   Gi/o  100.676672
# 22  6QNO          OPSD   Gi/o  106.282466

# %%
small[(p.table['angle']>0)&(small['Family']=='Gs')].reset_index(drop=True).sort_values('uniprot(gene)')
# Out:
#      PDB uniprot(gene) Family       angle
# 10  7JJO         ADRB1     Gs  151.778962
# 11  7BZ2         ADRB2     Gs   96.552165
# 12  7DHI         ADRB2     Gs   99.497969
# 13  7DHR         ADRB2     Gs  100.399835
# 14  6NI3         ADRB2     Gs  132.242103
# 0   7JVP          DRD1     Gs  137.348279
# 1   7JV5          DRD1     Gs  141.585709
# 5   7CKX          DRD1     Gs  145.747369
# 6   7CKY          DRD1     Gs  146.324558
# 7   7CKW          DRD1     Gs  147.305887
# 8   7CKZ          DRD1     Gs  147.238138
# 9   7CRH          DRD1     Gs  145.823230
# 2   7CFN         GPBAR     Gs  123.586484
# 3   7CFM         GPBAR     Gs  109.938859
# 4   7BW0         GPBAR     Gs  117.640831

# %%
small[(p.table['angle']>0)&(small['Family']=='Gq/11')].reset_index(drop=True).sort_values('uniprot(gene)')
# Out:
# Empty DataFrame
# Columns: [PDB, uniprot(gene), Family, angle]
# Index: []

# %%
df = p.dfl[p.dfl_list.index('7DHI')]

# %%
df
# Out:
#        PDB group_PDB auth_asym_id label_asym_id  label_seq_id auth_seq_id  \
# 0     7DHI      ATOM            A             A            13          12
# 1     7DHI      ATOM            A             A            13          12
# 2     7DHI      ATOM            A             A            13          12
# 3     7DHI      ATOM            A             A            13          12
# 4     7DHI      ATOM            A             A            13          12
# ...    ...       ...          ...           ...           ...         ...
# 7775  7DHI      ATOM            R             E           350         341
# 7776  7DHI      ATOM            R             E           350         341
# 7777  7DHI      ATOM            R             E           350         341
# 7778  7DHI      ATOM            R             E           350         341
# 7779  7DHI      ATOM            R             E           350         341
#
#      label_comp_id    id label_atom_id type_symbol  ...   identifier  \
# 0              GLN     1             N           N  ...  ADRB2_HUMAN
# 1              GLN     2            CA           C  ...  ADRB2_HUMAN
# 2              GLN     3             C           C  ...  ADRB2_HUMAN
# 3              GLN     4             O           O  ...  ADRB2_HUMAN
# 4              GLN     5            CB           C  ...  ADRB2_HUMAN
# ...            ...   ...           ...         ...  ...          ...
# 7775           CYS  7776            CA           C  ...  ADRB2_HUMAN
# 7776           CYS  7777             C           C  ...  ADRB2_HUMAN
# 7777           CYS  7778             O           O  ...  ADRB2_HUMAN
# 7778           CYS  7779            CB           C  ...  ADRB2_HUMAN
# 7779           CYS  7780            SG           S  ...  ADRB2_HUMAN
#
#      label_comp_sid label_2_uni  gen_pos  gen_pos1  gen_pos2 uniprot_comp_sid  \
# 0                 Q           0                0.0         0
# 1                 Q          11                0.0         0
# 2                 Q           0                0.0         0
# 3                 Q           0                0.0         0
# 4                 Q           0                0.0         0
# ...             ...         ...      ...       ...       ...              ...
# 7775              C         394                0.0         0
# 7776              C           0                0.0         0
# 7777              C           0                0.0         0
# 7778              C           0                0.0         0
# 7779              C           0                0.0         0
#
#      gprot_pos  uniprot_comp_id fam_comp_id
# 0
# 1      G.HN.29                Q           Q
# 2
# 3
# 4
# ...        ...              ...         ...
# 7775
# 7776
# 7777
# 7778
# 7779
#
# [7780 rows x 26 columns]

# %%
df[df['gprot_pos'].str.contains('HN')]
# Out:
#       PDB group_PDB auth_asym_id label_asym_id  label_seq_id auth_seq_id  \
# 1    7DHI      ATOM            A             A            13          12
# 6    7DHI      ATOM            A             A            14          13
# 11   7DHI      ATOM            A             A            15          14
# 19   7DHI      ATOM            A             A            16          15
# 24   7DHI      ATOM            A             A            17          16
# 33   7DHI      ATOM            A             A            18          17
# 38   7DHI      ATOM            A             A            19          18
# 43   7DHI      ATOM            A             A            20          19
# 52   7DHI      ATOM            A             A            21          20
# 63   7DHI      ATOM            A             A            22          21
# 68   7DHI      ATOM            A             A            23          22
# 73   7DHI      ATOM            A             A            24          23
# 81   7DHI      ATOM            A             A            25          24
# 90   7DHI      ATOM            A             A            26          25
# 99   7DHI      ATOM            A             A            27          26
# 107  7DHI      ATOM            A             A            28          27
# 116  7DHI      ATOM            A             A            29          28
# 125  7DHI      ATOM            A             A            30          29
# 134  7DHI      ATOM            A             A            31          30
# 142  7DHI      ATOM            A             A            32          31
# 151  7DHI      ATOM            A             A            33          32
# 160  7DHI      ATOM            A             A            34          33
# 168  7DHI      ATOM            A             A            35          34
# 177  7DHI      ATOM            A             A            36          35
# 186  7DHI      ATOM            A             A            37          36
#
#     label_comp_id   id label_atom_id type_symbol  ...   identifier  \
# 1             GLN    2            CA           C  ...  ADRB2_HUMAN
# 6             ARG    7            CA           C  ...  ADRB2_HUMAN
# 11            ASN   12            CA           C  ...  ADRB2_HUMAN
# 19            GLU   20            CA           C  ...  ADRB2_HUMAN
# 24            GLU   25            CA           C  ...  ADRB2_HUMAN
# 33            LYS   34            CA           C  ...  ADRB2_HUMAN
# 38            ALA   39            CA           C  ...  ADRB2_HUMAN
# 43            GLN   44            CA           C  ...  ADRB2_HUMAN
# 52            ARG   53            CA           C  ...  ADRB2_HUMAN
# 63            GLU   64            CA           C  ...  ADRB2_HUMAN
# 68            ALA   69            CA           C  ...  ADRB2_HUMAN
# 73            ASN   74            CA           C  ...  ADRB2_HUMAN
# 81            LYS   82            CA           C  ...  ADRB2_HUMAN
# 90            LYS   91            CA           C  ...  ADRB2_HUMAN
# 99            ILE  100            CA           C  ...  ADRB2_HUMAN
# 107           GLU  108            CA           C  ...  ADRB2_HUMAN
# 116           LYS  117            CA           C  ...  ADRB2_HUMAN
# 125           GLN  126            CA           C  ...  ADRB2_HUMAN
# 134           LEU  135            CA           C  ...  ADRB2_HUMAN
# 142           GLN  143            CA           C  ...  ADRB2_HUMAN
# 151           LYS  152            CA           C  ...  ADRB2_HUMAN
# 160           ASP  161            CA           C  ...  ADRB2_HUMAN
# 168           LYS  169            CA           C  ...  ADRB2_HUMAN
# 177           GLN  178            CA           C  ...  ADRB2_HUMAN
# 186           VAL  187            CA           C  ...  ADRB2_HUMAN
#
#     label_comp_sid label_2_uni  gen_pos  gen_pos1  gen_pos2 uniprot_comp_sid  \
# 1                Q          11                0.0         0
# 6                R          12                0.0         0
# 11               N          13                0.0         0
# 19               E          14                0.0         0
# 24               E          15                0.0         0
# 33               K          16                0.0         0
# 38               A          17                0.0         0
# 43               Q          18                0.0         0
# 52               R          19                0.0         0
# 63               E          20                0.0         0
# 68               A          21                0.0         0
# 73               N          22                0.0         0
# 81               K          23                0.0         0
# 90               K          24                0.0         0
# 99               I          25                0.0         0
# 107              E          26                0.0         0
# 116              K          27                0.0         0
# 125              Q          28                0.0         0
# 134              L          29                0.0         0
# 142              Q          30                0.0         0
# 151              K          31                0.0         0
# 160              D          32                0.0         0
# 168              K          33                0.0         0
# 177              Q          34                0.0         0
# 186              V          35                0.0         0
#
#     gprot_pos  uniprot_comp_id fam_comp_id
# 1     G.HN.29                Q           Q
# 6     G.HN.30                R           R
# 11    G.HN.31                N           N
# 19    G.HN.32                E           E
# 24    G.HN.33                E           E
# 33    G.HN.34                K           K
# 38    G.HN.35                A           A
# 43    G.HN.36                Q           Q
# 52    G.HN.37                R           R
# 63    G.HN.38                E           E
# 68    G.HN.39                A           A
# 73    G.HN.40                N           N
# 81    G.HN.41                K           K
# 90    G.HN.42                K           K
# 99    G.HN.43                I           I
# 107   G.HN.44                E           E
# 116   G.HN.45                K           K
# 125   G.HN.46                Q           Q
# 134   G.HN.47                L           L
# 142   G.HN.48                Q           Q
# 151   G.HN.49                K           K
# 160   G.HN.50                D           D
# 168   G.HN.51                K           K
# 177   G.HN.52                Q           Q
# 186   G.HN.53                V           V
#
# [25 rows x 26 columns]

# %%
df[(df['gen_pos1']>=8.5)&(df['gen_pos1']<=9)&(df['label_atom_id']=='CA')]
# Out:
#        PDB group_PDB auth_asym_id label_asym_id  label_seq_id auth_seq_id  \
# 7272  7DHI      ATOM            R             E           288         279
# 7280  7DHI      ATOM            R             E           289         280
# 7284  7DHI      ATOM            R             E           290         281
# 7291  7DHI      ATOM            R             E           291         282
# 7302  7DHI      ATOM            R             E           292         283
# 7309  7DHI      ATOM            R             E           293         284
# 7317  7DHI      ATOM            R             E           294         285
# 7322  7DHI      ATOM            R             E           295         286
# 7336  7DHI      ATOM            R             E           296         287
# 7344  7DHI      ATOM            R             E           297         288
#
#      label_comp_id    id label_atom_id type_symbol  ...   identifier  \
# 7272           MET  7273            CA           C  ...  ADRB2_HUMAN
# 7280           GLY  7281            CA           C  ...  ADRB2_HUMAN
# 7284           THR  7285            CA           C  ...  ADRB2_HUMAN
# 7291           PHE  7292            CA           C  ...  ADRB2_HUMAN
# 7302           THR  7303            CA           C  ...  ADRB2_HUMAN
# 7309           LEU  7310            CA           C  ...  ADRB2_HUMAN
# 7317           ALA  7318            CA           C  ...  ADRB2_HUMAN
# 7322           TRP  7323            CA           C  ...  ADRB2_HUMAN
# 7336           LEU  7337            CA           C  ...  ADRB2_HUMAN
# 7344           PRO  7345            CA           C  ...  ADRB2_HUMAN
#
#      label_comp_sid label_2_uni   gen_pos  gen_pos1  gen_pos2  \
# 7272              M         332  8.50x50?      8.50        50
# 7280              G         333  8.51x51?      8.51        51
# 7284              T         334  8.52x52?      8.52        52
# 7291              F         335  8.53x53?      8.53        53
# 7302              T         336  8.54x54?      8.54        54
# 7309              L         337  8.55x55?      8.55        55
# 7317              A         338  8.56x56?      8.56        56
# 7322              W         339  8.57x57?      8.57        57
# 7336              L         340   8.58x58      8.58        58
# 7344              P         341  8.59x59?      8.59        59
#
#      uniprot_comp_sid gprot_pos  uniprot_comp_id fam_comp_id
# 7272                F
# 7280                R
# 7284                I
# 7291                A
# 7302                F
# 7309                Q
# 7317                E
# 7322                L
# 7336                L
# 7344                C
#
# [10 rows x 26 columns]

# %%
small[small['Family']=='Gs'].reset_index(drop=True).sort_values('uniprot(gene)')#.to_csv('gs_angle_tm3_h5.csv')

# %%
small[small['Family']=='Gq/11'].reset_index(drop=True).sort_values('uniprot(gene)')#.to_csv('gq_angle_tm3_h5.csv')

# %%
plot_helices([[xyz_r, vector_r, mean_r, 'Receptor'], [xyz_g, vector_g, mean_g, 'Gprotein']]) # 	7E2Z

# %%
plot_helices([[xyz_r, vector_r, mean_r, 'Receptor'], [xyz_g, vector_g, mean_g, 'Gprotein']]) # 	7E2X

# %%
plot_helices([[xyz_r, vector_r, mean_r, 'Receptor'], [xyz_g, vector_g, mean_g, 'Gprotein']]) # 	7E2Y
