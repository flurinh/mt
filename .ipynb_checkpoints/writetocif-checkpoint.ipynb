# %%
from processor import *
from utils3 import *
from utils2 import *
import pandas as pd
import os
import sys
import functools
import operator
import random
from tqdm import tqdm, trange
import time
import numpy as np
import pandas
from math import degrees
import requests as r
from Bio import SeqIO, pairwise2
from io import StringIO
import gemmi
from gemmi import cif

# %%
PATH = 'data/'
STRUCTURE_PATH = PATH + 'mmcif/'
"""
self.remove_hetatm = remove_hetatm
self.allow_exception = allow_exception

self.filenames, self.pdb_ids = self.get_pdb_files()
self.filenames = self.filenames[starting_idx:]
self.pdb_ids = self.pdb_ids[starting_idx:]
if self.limit == None:
    self.limit = len(self.pdb_ids)
if len(self.filenames) > self.limit:
    self.filenames = self.filenames[:self.limit]
    self.pdb_ids = self.pdb_ids[:self.limit]"""

# Columns for structure dataframe
COLS = ['group_PDB', 'auth_asym_id', 'label_asym_id', 'label_seq_id', 'auth_seq_id', 
             'label_comp_id', 'id', 'label_atom_id', 
             'type_symbol', 'Cartn_x', 'Cartn_y', 'Cartn_z']

# %%
ALL_COLS = ['group_PDB' ,
'id' ,
'type_symbol' ,
'label_atom_id' ,
'label_alt_id' ,
'label_comp_id' ,
'label_asym_id' ,
'label_entity_id' ,
'label_seq_id' ,
'pdbx_PDB_ins_code' ,
'Cartn_x' ,
'Cartn_y' ,
'Cartn_z' ,
'occupancy' ,
'B_iso_or_equiv' ,
'pdbx_formal_charge' ,
'auth_seq_id' ,
'auth_comp_id' ,
'auth_asym_id' ,
'auth_atom_id' ,
'pdbx_PDB_model_num' ]

# %%
def load_cifs(pdb_id):
    path = 'data/mmcif/' + pdb_id + '.cif'
    try:
        doc = cif.read_file(path)  # copy all the data from mmCIF file
        lol = []  # list of lists
        for b, block in enumerate(doc):
            table = block.find('_atom_site.', COLS)
            for row in table:
                lol.append([pdb_id]+list(row))
    except Exception as e:
        print("Hoppla. %s" % e)
        sys.exit(1)
    cols = ['PDB']+COLS
    st = gemmi.read_structure(path)
    model = st[0]
    if len(st) > 1:
        print("There are multiple models!")
    rol = []
    for chain in model:
        for r, res in enumerate(chain.get_polymer()):
            # previous_residue() and next_residue() return previous/next
            # residue only if the residues are bonded. Otherwise -- None.
            prev_res = chain.previous_residue(res)
            next_res = chain.next_residue(res)
            try:
                phi, psi = gemmi.calculate_phi_psi(prev_res, res, next_res)
            except:
                phi, psi = np.nan, np.nan
            try:
                omega = gemmi.calculate_omega(res, next_res)
            except:
                omega = np.nan
            rol.append([res.label_seq, res.subchain, 
                        degrees(phi), degrees(omega), degrees(psi)])
    cols2 = ['label_seq_id', 'label_asym_id', 'phi', 'omega', 'psi']
    rol_df = pd.DataFrame(data=rol, columns=cols2)
    rol_df['label_seq_id'] = rol_df['label_seq_id'].astype(int)
    lol_df = pd.DataFrame(data=lol, columns=cols)
    lol_df['label_seq_id'] = lol_df.apply(lambda x: int(x.label_seq_id) if x.label_seq_id != '.' else np.nan, axis=1)
    return pd.merge(lol_df, rol_df, how='inner', on=['label_asym_id', 'label_seq_id'])

# %%
p = CifProcessor()
p.read_pkl_metainfo()
p.read_pkl(mode='rg', folder='data/processed/')
# Out:
# Reading files with generic numbers on receptors and gproteins.

# %%
len(p.dfl_list)
# Out:
# 557

# %%
f_act = p.filter_dfl_via_table(State='Active')

# %%
p.apply_filter(f_act)

# %%
f_act.head(20)
# Out:
#    uniprot(gene)      receptor family                           Cl.  \
# 0           STE2                 STE2  D1(Ste2-likefungalpheromone)
# 5          PE2R3           Prostanoid                  A(Rhodopsin)
# 6          5HT1B  5-Hydroxytryptamine                  A(Rhodopsin)
# 8          PTH1R   Parathyroidhormone                  B1(Secretin)
# 9          PTH1R   Parathyroidhormone                  B1(Secretin)
# 10         PTH1R   Parathyroidhormone                  B1(Secretin)
# 19          DRD1             Dopamine                  A(Rhodopsin)
# 20          DRD2             Dopamine                  A(Rhodopsin)
# 21          DRD1             Dopamine                  A(Rhodopsin)
# 22          DRD1             Dopamine                  A(Rhodopsin)
# 23         ADA2B        Adrenoceptors                  A(Rhodopsin)
# 24         ADA2B        Adrenoceptors                  A(Rhodopsin)
# 25          NTR1          Neurotensin                  A(Rhodopsin)
# 26          NTR1          Neurotensin                  A(Rhodopsin)
# 27          CCR6            Chemokine                  A(Rhodopsin)
# 34         CXCR2            Chemokine                  A(Rhodopsin)
# 35         CXCR2            Chemokine                  A(Rhodopsin)
# 49         PE2R2           Prostanoid                  A(Rhodopsin)
# 50         PE2R2           Prostanoid                  A(Rhodopsin)
# 51         PE2R2           Prostanoid                  A(Rhodopsin)
#
#                    Species   Method   PDB  Resolution Preferred Chain   State  \
# 0   strainATCC204508/S288c  cryo-EM  7AD3         3.5               A  Active
# 5                    Human    X-ray  6AK3         2.9               B  Active
# 6                    Human  cryo-EM  6G79         3.8               S  Active
# 8                    Human  cryo-EM  6NBI         4.0               R  Active
# 9                    Human  cryo-EM  6NBF         3.0               R  Active
# 10                   Human  cryo-EM  6NBH         3.5               R  Active
# 19                   Human  cryo-EM  7JVP         2.9               R  Active
# 20                   Human  cryo-EM  7JVR         2.8               R  Active
# 21                   Human  cryo-EM  7JVQ         3.0               R  Active
# 22                   Human  cryo-EM  7JV5         3.0               R  Active
# 23                   Human  cryo-EM  6K42         4.1               R  Active
# 24                   Human  cryo-EM  6K41         2.9               R  Active
# 25                   Human  cryo-EM  6OS9         3.0               R  Active
# 26                   Human  cryo-EM  6OSA         3.0               R  Active
# 27                   Human  cryo-EM  6WWZ         3.3               R  Active
# 34                   Human  cryo-EM  6LFO         3.4               R  Active
# 35                   Human  cryo-EM  6LFM         3.5               R  Active
# 49                   Human  cryo-EM  7CX4         2.9               R  Active
# 50                   Human  cryo-EM  7CX2         2.8               R  Active
# 51                   Human  cryo-EM  7CX3         2.8               R  Active
#
#    Degree active %      Family Subtype Function
# 0                -  GPa1family    αPa1  Agonist
# 5               83           -       -  Agonist
# 6              100        Gi/o      αo  Agonist
# 8              100          Gs      αs  Agonist
# 9              100          Gs      αs  Agonist
# 10             100          Gs      αs  Agonist
# 19             100          Gs      αs  Agonist
# 20             100        Gi/o     αi1  Agonist
# 21             100          Gs      αs  Agonist
# 22             100          Gs      αs  Agonist
# 23             100        Gi/o     αi1  Agonist
# 24             100        Gi/o      αo  Agonist
# 25             100        Gi/o     αi1  Agonist
# 26             100        Gi/o     αi1  Agonist
# 27             100        Gi/o      αo  Agonist
# 34             100        Gi/o     αi1  Agonist
# 35             100        Gi/o     αi1  Agonist
# 49             100          Gs      αs  Agonist
# 50             100          Gs      αs  Agonist
# 51             100          Gs      αs  Agonist

# %%
structure = p.dfl[p.dfl_list.index('7JVR')]

# %%
structure
# Out:
#        PDB group_PDB auth_asym_id label_asym_id  label_seq_id auth_seq_id  \
# 0     7JVR      ATOM            R             A           179          34
# 1     7JVR      ATOM            R             A           179          34
# 2     7JVR      ATOM            R             A           179          34
# 3     7JVR      ATOM            R             A           179          34
# 4     7JVR      ATOM            R             A           179          34
# ...    ...       ...          ...           ...           ...         ...
# 8824  7JVR      ATOM            E             E           247         247
# 8825  7JVR      ATOM            E             E           247         247
# 8826  7JVR      ATOM            E             E           247         247
# 8827  7JVR      ATOM            E             E           247         247
# 8828  7JVR      ATOM            E             E           247         247
#
#      label_comp_id    id label_atom_id type_symbol  ...  identifier  \
# 0              TYR     1             N           N  ...  DRD2_HUMAN
# 1              TYR     2            CA           C  ...  DRD2_HUMAN
# 2              TYR     3             C           C  ...  DRD2_HUMAN
# 3              TYR     4             O           O  ...  DRD2_HUMAN
# 4              TYR     5            CB           C  ...  DRD2_HUMAN
# ...            ...   ...           ...         ...  ...         ...
# 8824           LEU  8825             O           O  ...  DRD2_HUMAN
# 8825           LEU  8826            CB           C  ...  DRD2_HUMAN
# 8826           LEU  8827            CG           C  ...  DRD2_HUMAN
# 8827           LEU  8828           CD1           C  ...  DRD2_HUMAN
# 8828           LEU  8829           CD2           C  ...  DRD2_HUMAN
#
#      label_comp_sid label_2_uni  gen_pos  gen_pos1  gen_pos2 uniprot_comp_sid  \
# 0                 Y           0               0.00       0.0
# 1                 Y          34  1.32x32      1.32      32.0                Y
# 2                 Y           0               0.00       0.0
# 3                 Y           0               0.00       0.0
# 4                 Y           0               0.00       0.0
# ...             ...         ...      ...       ...       ...              ...
# 8824              L           0               0.00       0.0
# 8825              L           0               0.00       0.0
# 8826              L           0               0.00       0.0
# 8827              L           0               0.00       0.0
# 8828              L           0               0.00       0.0
#
#      gprot_pos  uniprot_comp_id fam_comp_id
# 0
# 1
# 2
# 3
# 4
# ...        ...              ...         ...
# 8824
# 8825
# 8826
# 8827
# 8828
#
# [8829 rows x 26 columns]

# %%
structure[structure['gprot_pos']!='']
# Out:
#        PDB group_PDB auth_asym_id label_asym_id  label_seq_id auth_seq_id  \
# 2165  7JVR      ATOM            A             B             5           5
# 2173  7JVR      ATOM            A             B             6           6
# 2179  7JVR      ATOM            A             B             7           7
# 2184  7JVR      ATOM            A             B             8           8
# 2193  7JVR      ATOM            A             B             9           9
# ...    ...       ...          ...           ...           ...         ...
# 3934  7JVR      ATOM            A             B           350         350
# 3942  7JVR      ATOM            A             B           351         351
# 3948  7JVR      ATOM            A             B           352         352
# 3952  7JVR      ATOM            A             B           353         353
# 3960  7JVR      ATOM            A             B           354         354
#
#      label_comp_id    id label_atom_id type_symbol  ...  identifier  \
# 2165           LEU  2166            CA           C  ...  DRD2_HUMAN
# 2173           SER  2174            CA           C  ...  DRD2_HUMAN
# 2179           ALA  2180            CA           C  ...  DRD2_HUMAN
# 2184           GLU  2185            CA           C  ...  DRD2_HUMAN
# 2193           ASP  2194            CA           C  ...  DRD2_HUMAN
# ...            ...   ...           ...         ...  ...         ...
# 3934           ASP  3935            CA           C  ...  DRD2_HUMAN
# 3942           CYS  3943            CA           C  ...  DRD2_HUMAN
# 3948           GLY  3949            CA           C  ...  DRD2_HUMAN
# 3952           LEU  3953            CA           C  ...  DRD2_HUMAN
# 3960           PHE  3961            CA           C  ...  DRD2_HUMAN
#
#      label_comp_sid label_2_uni  gen_pos  gen_pos1  gen_pos2 uniprot_comp_sid  \
# 2165              L           4                0.0       0.0
# 2173              S           5                0.0       0.0
# 2179              A           6                0.0       0.0
# 2184              E           7                0.0       0.0
# 2193              D           8                0.0       0.0
# ...             ...         ...      ...       ...       ...              ...
# 3934              D         349                0.0       0.0
# 3942              C         350                0.0       0.0
# 3948              G         351                0.0       0.0
# 3952              L         352                0.0       0.0
# 3960              F         353                0.0       0.0
#
#      gprot_pos  uniprot_comp_id fam_comp_id
# 2165   G.HN.11                L           L
# 2173   G.HN.30                S           S
# 2179   G.HN.31                A           A
# 2184   G.HN.32                E           E
# 2193   G.HN.33                D           D
# ...        ...              ...         ...
# 3934   G.H5.22                D           D
# 3942   G.H5.23                C           C
# 3948   G.H5.24                G           G
# 3952   G.H5.25                L           L
# 3960   G.H5.26                F           F
#
# [224 rows x 26 columns]

# %%
def spread_gen_pos_to_residue_atoms(structure):
    try:
        if 'gprot_pos' in list(structure.columns):
            structure['generic_position'] = structure.apply(lambda x: x.gen_pos if x.gprot_pos == '' else x.gprot_pos, axis=1)
            c_gprot = list(structure[structure['gprot_pos'] != '']['label_asym_id'])
        else:
            structure['generic_position'] = structure['gen_pos']
            c_gprot = []
        residue_seq_ids = list(set(list(structure['label_seq_id'])))
        chains = list(set(list(structure['label_asym_id'])))
        # for all chains
        for c in tqdm(chains):
            c_rec = list(structure[structure['gen_pos'] != '']['label_asym_id'])
            check_gen_pos_chains = list(set(c_rec+c_gprot))
            # check if chain has residues with a generic position number
            if c in check_gen_pos_chains:
                # for all residues
                for rsi in tqdm(residue_seq_ids):
                    block_gen_pos_ = structure[(structure['label_seq_id']==rsi) &
                                               (structure['label_asym_id']==c) &
                                               (structure['generic_position']!='')]
                    if len(block_gen_pos_)>0: 
                        block_idxs = list(structure[(structure['label_seq_id']==rsi) &
                                                    (structure['label_asym_id']==c)].index)
                        block_gen_pos = block_gen_pos_['generic_position'].iloc[0]
                        # for all indexes within that residue
                        for idx in block_idxs:
                            structure.loc[idx, 'generic_position'] = block_gen_pos
        return structure
    except:
        print(structure['PDB'].iloc[0])

# %%
df = spread_gen_pos_to_residue_atoms(structure)
# Out:
#   0%|                                                                                                                               | 0/5 [00:00<?, ?it/s]
#   0%|                                                                                                                             | 0/447 [00:00<?, ?it/s]
#   6%|██████▉                                                                                                            | 27/447 [00:00<00:01, 269.94it/s]
#  12%|█████████████▉                                                                                                     | 54/447 [00:00<00:01, 256.37it/s]
#  28%|████████████████████████████████▍                                                                                 | 127/447 [00:00<00:00, 464.46it/s]
#  42%|███████████████████████████████████████████████▉                                                                  | 188/447 [00:00<00:00, 520.73it/s]
#  54%|█████████████████████████████████████████████████████████████▍                                                    | 241/447 [00:00<00:00, 369.91it/s]
#  64%|████████████████████████████████████████████████████████████████████████▍                                         | 284/447 [00:00<00:00, 322.67it/s]
#  72%|█████████████████████████████████████████████████████████████████████████████████▊                                | 321/447 [00:00<00:00, 297.59it/s]
#  79%|██████████████████████████████████████████████████████████████████████████████████████████▎                       | 354/447 [00:01<00:00, 284.52it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 447/447 [00:01<00:00, 369.34it/s]
#  60%|███████████████████████████████████████████████████████████████████████▍                                               | 3/5 [00:01<00:00,  2.47it/s]
#   0%|                                                                                                                             | 0/447 [00:00<?, ?it/s]
#  17%|███████████████████▊                                                                                               | 77/447 [00:00<00:00, 762.27it/s]
#  34%|███████████████████████████████████████▎                                                                          | 154/447 [00:00<00:00, 753.45it/s]
#  51%|██████████████████████████████████████████████████████████▋                                                       | 230/447 [00:00<00:00, 473.98it/s]
#  64%|████████████████████████████████████████████████████████████████████████▉                                         | 286/447 [00:00<00:00, 369.90it/s]
#  74%|████████████████████████████████████████████████████████████████████████████████████▏                             | 330/447 [00:00<00:00, 345.13it/s]
#  83%|██████████████████████████████████████████████████████████████████████████████████████████████                    | 369/447 [00:00<00:00, 314.90it/s]
#  90%|██████████████████████████████████████████████████████████████████████████████████████████████████████▊           | 403/447 [00:01<00:00, 295.88it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 447/447 [00:01<00:00, 352.45it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:02<00:00,  2.01it/s]

# %%
df[df['generic_position']!='']
# Out:
#        PDB group_PDB auth_asym_id label_asym_id  label_seq_id auth_seq_id  \
# 0     7JVR      ATOM            R             A           179          34
# 1     7JVR      ATOM            R             A           179          34
# 2     7JVR      ATOM            R             A           179          34
# 3     7JVR      ATOM            R             A           179          34
# 4     7JVR      ATOM            R             A           179          34
# ...    ...       ...          ...           ...           ...         ...
# 3966  7JVR      ATOM            A             B           354         354
# 3967  7JVR      ATOM            A             B           354         354
# 3968  7JVR      ATOM            A             B           354         354
# 3969  7JVR      ATOM            A             B           354         354
# 3970  7JVR      ATOM            A             B           354         354
#
#      label_comp_id    id label_atom_id type_symbol  ... label_comp_sid  \
# 0              TYR     1             N           N  ...              Y
# 1              TYR     2            CA           C  ...              Y
# 2              TYR     3             C           C  ...              Y
# 3              TYR     4             O           O  ...              Y
# 4              TYR     5            CB           C  ...              Y
# ...            ...   ...           ...         ...  ...            ...
# 3966           PHE  3967           CD2           C  ...              F
# 3967           PHE  3968           CE1           C  ...              F
# 3968           PHE  3969           CE2           C  ...              F
# 3969           PHE  3970            CZ           C  ...              F
# 3970           PHE  3971           OXT           O  ...              F
#
#      label_2_uni  gen_pos  gen_pos1  gen_pos2  uniprot_comp_sid gprot_pos  \
# 0              0               0.00       0.0
# 1             34  1.32x32      1.32      32.0                 Y
# 2              0               0.00       0.0
# 3              0               0.00       0.0
# 4              0               0.00       0.0
# ...          ...      ...       ...       ...               ...       ...
# 3966           0               0.00       0.0
# 3967           0               0.00       0.0
# 3968           0               0.00       0.0
# 3969           0               0.00       0.0
# 3970           0               0.00       0.0
#
#      uniprot_comp_id  fam_comp_id generic_position
# 0                                          1.32x32
# 1                                          1.32x32
# 2                                          1.32x32
# 3                                          1.32x32
# 4                                          1.32x32
# ...              ...          ...              ...
# 3966                                       G.H5.26
# 3967                                       G.H5.26
# 3968                                       G.H5.26
# 3969                                       G.H5.26
# 3970                                       G.H5.26
#
# [3873 rows x 27 columns]

# %%
def write_cif_with_gen_seq_numbers(structure, replace_idx=-4):
    pdb_id = structure['PDB'].iloc[0]
    path = 'data/mmcif/' + pdb_id + '.cif'
    doc = cif.read_file(path)  # copy all the data from mmCIF file
    lol = []  # list of lists
    for b, block in enumerate(doc):
        col_overwrite = block.find('_atom_site.', ['id'])
        table = block.find('_atom_site.', ALL_COLS)
        for r, row in enumerate(table):
            if row[1] in list(structure['id']):
                gen_pos = structure[structure['id']==row[1]]['generic_position'].iloc[0]
                if gen_pos == '':
                    gen_pos = '-'
                row[replace_idx] = gen_pos
            else:
                row[replace_idx] = '-'
    return doc

# %%
df = spread_gen_pos_to_residue_atoms(structure)
doc = write_cif_with_gen_seq_numbers(df, replace_idx = -7)
doc.write_file('data/modified/'+df['PDB'].iloc[0]+'_modified.cif')
