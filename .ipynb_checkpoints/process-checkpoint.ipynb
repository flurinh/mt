# %%
from processor import *
from scipy.spatial.distance import cdist, pdist
import seaborn as sns
from matplotlib import rcParams

# %%
p = CifProcessor()

# %%
p.get_metatable()

# %%
p.read_pkl_metainfo()

# %%
p.read_pkl_processed()

# %%
p.table['Family'].unique()
# Out:
# array(['GPa1family', '-', 'Gi/o', 'Gs', 'Beta', 'Gq/11', 'Visual'],
#       dtype=object)

# %%
f = p.filter_dfl_via_table(State='Active', Cl='A', gprotein=True)

# %%
p.assign_generic_numbers_g(pdb_ids=None, overwrite=True, f = f, folder = 'data/raw/')
# Out:
#   0%|                                                                                                                                                                                                                                                                                           | 0/13 [00:00<?, ?it/s]
# Downloading uniprot gprotein sequences...
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 13/13 [00:15<00:00,  1.17s/it]
#  37%|██████████████████████████████████████████████████████████████████████████████████████████████████████▏                                                                                                                                                                           | 25/67 [00:17<00:31,  1.35it/s]
# Did not find label_seq_ids
#  66%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉                                                                                              | 44/67 [00:30<00:15,  1.51it/s]
# Did not find label_seq_ids
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 67/67 [00:41<00:00,  1.63it/s]

# %%
f_gio
# Out:
#    uniprot(gene)            receptor family           Cl. Species   Method  \
# 0           NTR1                Neurotensin  A(Rhodopsin)   Human  cryo-EM
# 1           NTR1                Neurotensin  A(Rhodopsin)   Human  cryo-EM
# 2          CXCR2                  Chemokine  A(Rhodopsin)   Human  cryo-EM
# 3          CXCR2                  Chemokine  A(Rhodopsin)   Human  cryo-EM
# 4          ADA2B              Adrenoceptors  A(Rhodopsin)   Human  cryo-EM
# 5          ADA2B              Adrenoceptors  A(Rhodopsin)   Human  cryo-EM
# 6          5HT1B        5-Hydroxytryptamine  A(Rhodopsin)   Human  cryo-EM
# 7           DRD2                   Dopamine  A(Rhodopsin)   Human  cryo-EM
# 8           CCR6                  Chemokine  A(Rhodopsin)   Human  cryo-EM
# 9          AGRG3                      ADGRG  B2(Adhesion)   Human  cryo-EM
# 10         AGRG3                      ADGRG  B2(Adhesion)   Human  cryo-EM
# 11          ACM2  Acetylcholine(muscarinic)  A(Rhodopsin)   Human  cryo-EM
# 12          CNR2                Cannabinoid  A(Rhodopsin)   Human  cryo-EM
# 13          DRD3                   Dopamine  A(Rhodopsin)   Human  cryo-EM
# 14          DRD3                   Dopamine  A(Rhodopsin)   Human  cryo-EM
# 15          CNR1                Cannabinoid  A(Rhodopsin)   Human  cryo-EM
# 16          AA1R                  Adenosine  A(Rhodopsin)   Human  cryo-EM
# 17           SMO                   Frizzled   F(Frizzled)   Human  cryo-EM
# 18           SMO                   Frizzled   F(Frizzled)   Human  cryo-EM
# 19           SMO                   Frizzled   F(Frizzled)   Human  cryo-EM
# 20           SMO                   Frizzled   F(Frizzled)   Human  cryo-EM
# 21          OPSD                     Opsins  A(Rhodopsin)  Bovine    X-ray
# 22          OPSD                     Opsins  A(Rhodopsin)  Bovine    X-ray
# 23          OPSD                     Opsins  A(Rhodopsin)  Bovine    X-ray
# 24          CNR2                Cannabinoid  A(Rhodopsin)   Human  cryo-EM
# 25          CNR1                Cannabinoid  A(Rhodopsin)   Human  cryo-EM
# 26          FPR2              Formylpeptide  A(Rhodopsin)   Human  cryo-EM
# 27          OPSD                     Opsins  A(Rhodopsin)  Bovine  cryo-EM
# 28          OPSD                     Opsins  A(Rhodopsin)  Bovine  cryo-EM
# 29          OPSD                     Opsins  A(Rhodopsin)  Bovine    X-ray
# 30          DRD2                   Dopamine  A(Rhodopsin)   Human  cryo-EM
# 31          OPSD                     Opsins  A(Rhodopsin)  Bovine    X-ray
# 32          OPSD                     Opsins  A(Rhodopsin)  Bovine    X-ray
# 33           SMO                   Frizzled   F(Frizzled)   Human  cryo-EM
# 34          OPRM                     Opioid  A(Rhodopsin)   Mouse  cryo-EM
# 35          OPRM                     Opioid  A(Rhodopsin)   Mouse  cryo-EM
# 36          OPSD                     Opsins  A(Rhodopsin)   Human  cryo-EM
# 37           GLR                   Glucagon  B1(Secretin)   Human  cryo-EM
# 38          OPSD                     Opsins  A(Rhodopsin)  Bovine    X-ray
# 39          OPSD                     Opsins  A(Rhodopsin)  Bovine    X-ray
# 40          OPSD                     Opsins  A(Rhodopsin)  Bovine  cryo-EM
# 41          NTR1                Neurotensin  A(Rhodopsin)     Rat  cryo-EM
# 42          OPSD                     Opsins  A(Rhodopsin)  Bovine    X-ray
# 43          NTR1                Neurotensin  A(Rhodopsin)     Rat  cryo-EM
# 44          OPSD                     Opsins  A(Rhodopsin)  Bovine    X-ray
# 45          OPSD                     Opsins  A(Rhodopsin)  Bovine    X-ray
# 46          OPSD                     Opsins  A(Rhodopsin)  Bovine    X-ray
# 47          NTR1                Neurotensin  A(Rhodopsin)     Rat  cryo-EM
# 48          NTR1                Neurotensin  A(Rhodopsin)     Rat  cryo-EM
#
#      PDB  Resolution Preferred Chain   State Degree active % Family Subtype  \
# 0   6OSA         3.0               R  Active             100   Gi/o     αi1
# 1   6OS9         3.0               R  Active             100   Gi/o     αi1
# 2   6LFM         3.5               R  Active             100   Gi/o     αi1
# 3   6LFO         3.4               R  Active             100   Gi/o     αi1
# 4   6K42         4.1               R  Active             100   Gi/o     αi1
# 5   6K41         2.9               R  Active             100   Gi/o      αo
# 6   6G79         3.8               S  Active             100   Gi/o      αo
# 7   7JVR         2.8               R  Active             100   Gi/o     αi1
# 8   6WWZ         3.3               R  Active             100   Gi/o      αo
# 9   7D77         2.9               R  Active               -   Gi/o      αo
# 10  7D76         3.1               R  Active               -   Gi/o      αo
# 11  6OIK         3.6               R  Active             100   Gi/o      αo
# 12  6PT0         3.2               R  Active             100   Gi/o     αi1
# 13  7CMU         3.0               R  Active             100   Gi/o     αi1
# 14  7CMV         2.7               R  Active             100   Gi/o     αi1
# 15  6N4B         3.0               R  Active             100   Gi/o     αi1
# 16  6D9H         3.6               R  Active             100   Gi/o     αi2
# 17  6XBK         3.2               R  Active             100   Gi/o     αi1
# 18  6XBM         3.2               R  Active             100   Gi/o     αi1
# 19  6XBJ         3.9               R  Active             100   Gi/o     αi1
# 20  6XBL         3.9               R  Active             100   Gi/o     αi1
# 21  2X72         3.0               A  Active              94   Gi/o     αt1
# 22  3PQR         2.9               A  Active              94   Gi/o     αt1
# 23  4J4Q         2.7               A  Active              94   Gi/o     αt1
# 24  6KPF         2.9               R  Active             100   Gi/o     αi1
# 25  6KPG         3.0               R  Active             100   Gi/o     αi1
# 26  6OMM         3.2               R  Active             100   Gi/o     αi1
# 27  6OYA         3.3               R  Active             100   Gi/o     αt1
# 28  6OY9         3.9               R  Active             100   Gi/o     αt1
# 29  4X1H         2.3               A  Active              94   Gi/o     αt1
# 30  6VMS         3.8               R  Active             100   Gi/o     αi1
# 31  3DQB         3.2               A  Active              94   Gi/o     αt1
# 32  5WKT         3.2               A  Active              94   Gi/o     αt1
# 33  6OT0         3.9               R  Active             100   Gi/o     αi1
# 34  6DDF         3.5               R  Active             100   Gi/o     αi1
# 35  6DDE         3.5               R  Active             100   Gi/o     αi1
# 36  6CMO         4.5               R  Active              73   Gi/o     αi1
# 37  6LML         3.9               R  Active             100   Gi/o     αi1
# 38  6FUF         3.1               A  Active             100   Gi/o      αo
# 39  4BEY         2.9               A  Active              94   Gi/o     αt1
# 40  6QNO         4.4               R  Active             100   Gi/o     αi1
# 41  7L0Q         4.3               C  Active             100   Gi/o     αi1
# 42  6NWE         2.7               A  Active              94   Gi/o     αt1
# 43  7L0R         4.2               C  Active             100   Gi/o     αi1
# 44  6PGS         2.9               A  Active              94   Gi/o     αt1
# 45  6PEL         3.2               A  Active              94   Gi/o     αt1
# 46  6PH7         2.9               A  Active              94   Gi/o     αt1
# 47  7L0S         4.5               C  Active             100   Gi/o     αi1
# 48  7L0P         4.1               C  Active             100   Gi/o     αi1
#
#          Function
# 0         Agonist
# 1         Agonist
# 2         Agonist
# 3         Agonist
# 4         Agonist
# 5         Agonist
# 6         Agonist
# 7         Agonist
# 8         Agonist
# 9         Agonist
# 10        Agonist
# 11     AgonistPAM
# 12        Agonist
# 13        Agonist
# 14        Agonist
# 15        Agonist
# 16        Agonist
# 17        Agonist
# 18     AgonistPAM
# 19        Agonist
# 20     AgonistPAM
# 21        Agonist
# 22        Agonist
# 23        unknown
# 24        Agonist
# 25        Agonist
# 26        Agonist
# 27        Agonist
# 28        Agonist
# 29        unknown
# 30        Agonist
# 31  Apo(noligand)
# 32        unknown
# 33        Agonist
# 34        Agonist
# 35        Agonist
# 36  Apo(noligand)
# 37        Agonist
# 38        Agonist
# 39  Apo(noligand)
# 40        Agonist
# 41        Agonist
# 42        unknown
# 43        Agonist
# 44        unknown
# 45        unknown
# 46        unknown
# 47        Agonist
# 48        Agonist

# %%
f_gio = p.filter_dfl_via_table(State='Active', Cl='A', Family='Gi/o', gprotein=True)

# %%
f_gs = p.filter_dfl_via_table(State='Active', Cl='A', Family='Gs', gprotein=True)

# %%
f_q11 = p.filter_dfl_via_table(State='Active', Cl='A', Family='Gq/11', gprotein=True)

# %%
filtered_indices_gio = [x for x in p.get_dfl_indices(list(f_gio['PDB'])) if x != None]

# %%
filtered_indices_gs = [x for x in p.get_dfl_indices(list(f_gs['PDB'])) if x != None]

# %%
filtered_indices_q11 = [x for x in p.get_dfl_indices(list(f_q11['PDB'])) if x != None]

# %%
f_gs
# Out:
#    uniprot(gene) receptor family           Cl.     Species   Method   PDB  \
# 0           DRD1        Dopamine  A(Rhodopsin)       Human  cryo-EM  7JVQ
# 1           DRD1        Dopamine  A(Rhodopsin)       Human  cryo-EM  7JV5
# 2           DRD1        Dopamine  A(Rhodopsin)       Human  cryo-EM  7JVP
# 3          GPR52        Aorphans  A(Rhodopsin)       Human  cryo-EM  6LI3
# 4          GPBAR        Bileacid  A(Rhodopsin)       Human  cryo-EM  7CFM
# 5          GPBAR        Bileacid  A(Rhodopsin)       Human  cryo-EM  7CFN
# 6          AA2AR       Adenosine  A(Rhodopsin)       Human    X-ray  5G53
# 7           OX2R          Orexin  A(Rhodopsin)       Human  cryo-EM  7L1U
# 8           OX2R          Orexin  A(Rhodopsin)       Human  cryo-EM  7L1V
# 9          ADRB2   Adrenoceptors  A(Rhodopsin)       Human    X-ray  3SN6
# 10         GPBAR        Bileacid  A(Rhodopsin)       Human  cryo-EM  7BW0
# 11         AA2AR       Adenosine  A(Rhodopsin)       Human  cryo-EM  6GDG
# 12          DRD1        Dopamine  A(Rhodopsin)       Human  cryo-EM  7CKZ
# 13          DRD1        Dopamine  A(Rhodopsin)       Human  cryo-EM  7CKW
# 14          DRD1        Dopamine  A(Rhodopsin)       Human  cryo-EM  7CKX
# 15          DRD1        Dopamine  A(Rhodopsin)       Human  cryo-EM  7CKY
# 16          DRD1        Dopamine  A(Rhodopsin)       Human  cryo-EM  7CRH
# 17         ADRB2   Adrenoceptors  A(Rhodopsin)       Human    X-ray  6E67
# 18         ADRB1   Adrenoceptors  A(Rhodopsin)  Wildturkey  cryo-EM  7JJO
# 19          DRD1        Dopamine  A(Rhodopsin)       Human  cryo-EM  7LJD
# 20          DRD1        Dopamine  A(Rhodopsin)       Human  cryo-EM  7LJC
# 21         ADRB2   Adrenoceptors  A(Rhodopsin)       Human  cryo-EM  7BZ2
# 22         ADRB2   Adrenoceptors  A(Rhodopsin)       Human  cryo-EM  7DHI
# 23         ADRB2   Adrenoceptors  A(Rhodopsin)       Human  cryo-EM  7DHR
# 24         ADRB2   Adrenoceptors  A(Rhodopsin)       Human  cryo-EM  6NI3
# 25         PE2R4      Prostanoid  A(Rhodopsin)       Human  cryo-EM  7D7M
#
#     Resolution Preferred Chain   State Degree active % Family Subtype  \
# 0          3.0               R  Active             100     Gs      αs
# 1          3.0               R  Active             100     Gs      αs
# 2          2.9               R  Active             100     Gs      αs
# 3          3.3               R  Active             100     Gs      αs
# 4          3.0               R  Active             100     Gs      αs
# 5          3.0               R  Active             100     Gs      αs
# 6          3.4               A  Active             100     Gs      αs
# 7          3.2               R  Active             100     Gs      αs
# 8          3.0               R  Active             100     Gs      αs
# 9          3.2               R  Active             100     Gs      αs
# 10         3.9               R  Active             100     Gs      αs
# 11         4.1               A  Active             100     Gs      αs
# 12         3.1               R  Active             100     Gs      αs
# 13         3.2               R  Active             100     Gs      αs
# 14         3.5               R  Active             100     Gs      αs
# 15         3.2               R  Active             100     Gs      αs
# 16         3.3               R  Active             100     Gs      αs
# 17         3.7               B  Active             100     Gs      αs
# 18         2.6               R  Active             100     Gs      αs
# 19         3.2               R  Active             100     Gs      αs
# 20         3.0               R  Active             100     Gs      αs
# 21         3.8               R  Active             100     Gs      αs
# 22         3.3               R  Active             100     Gs      αs
# 23         3.8               R  Active             100     Gs      αs
# 24         3.8               R  Active             100     Gs      αs
# 25         3.3               A  Active             100     Gs      αs
#
#          Function
# 0         Agonist
# 1         Agonist
# 2         Agonist
# 3   Apo(noligand)
# 4         Agonist
# 5      AgonistPAM
# 6         Agonist
# 7         Agonist
# 8         Agonist
# 9         Agonist
# 10              -
# 11        Agonist
# 12     AgonistPAM
# 13        Agonist
# 14        Agonist
# 15        Agonist
# 16        Agonist
# 17        Agonist
# 18        Agonist
# 19     AgonistPAM
# 20     AgonistPAM
# 21        Agonist
# 22        Agonist
# 23        Agonist
# 24        Agonist
# 25        Agonist

# %%
huh = p.dfl[382]

# %%
huh
# Out:
#        PDB group_PDB auth_asym_id label_asym_id  label_seq_id auth_seq_id  \
# 0     6OIJ      ATOM            A             A             3           3
# 1     6OIJ      ATOM            A             A             3           3
# 2     6OIJ      ATOM            A             A             3           3
# 3     6OIJ      ATOM            A             A             3           3
# 4     6OIJ      ATOM            A             A             3           3
# ...    ...       ...          ...           ...           ...         ...
# 8788  6OIJ      ATOM            G             E            63          63
# 8789  6OIJ      ATOM            G             E            63          63
# 8790  6OIJ      ATOM            G             E            63          63
# 8791  6OIJ      ATOM            G             E            63          63
# 8792  6OIJ      ATOM            G             E            63          63
#
#      label_comp_id    id label_atom_id type_symbol  ...  identifier  \
# 0              CYS     1             N           N  ...  ACM1_HUMAN
# 1              CYS     2            CA           C  ...  ACM1_HUMAN
# 2              CYS     3             C           C  ...  ACM1_HUMAN
# 3              CYS     4             O           O  ...  ACM1_HUMAN
# 4              CYS     5            CB           C  ...  ACM1_HUMAN
# ...            ...   ...           ...         ...  ...         ...
# 8788           GLU  8789             N           N  ...  ACM1_HUMAN
# 8789           GLU  8790            CA           C  ...  ACM1_HUMAN
# 8790           GLU  8791             C           C  ...  ACM1_HUMAN
# 8791           GLU  8792             O           O  ...  ACM1_HUMAN
# 8792           GLU  8793            CB           C  ...  ACM1_HUMAN
#
#      label_comp_sid label_2_uni  gen_pos  uniprot_comp_sid  gen_pos1 gen_pos2  \
# 0                 C         NaN                                  0.0        0
# 1                 C         NaN                                  0.0        0
# 2                 C         NaN                                  0.0        0
# 3                 C         NaN                                  0.0        0
# 4                 C         NaN                                  0.0        0
# ...             ...         ...      ...               ...       ...      ...
# 8788              E         NaN                                  0.0        0
# 8789              E         NaN                                  0.0        0
# 8790              E         NaN                                  0.0        0
# 8791              E         NaN                                  0.0        0
# 8792              E         NaN                                  0.0        0
#
#      gprot_pos  uniprot_comp_id fam_comp_id
# 0                           NaN         NaN
# 1                           NaN         NaN
# 2                           NaN         NaN
# 3                           NaN         NaN
# 4                           NaN         NaN
# ...        ...              ...         ...
# 8788                        NaN         NaN
# 8789                        NaN         NaN
# 8790                        NaN         NaN
# 8791                        NaN         NaN
# 8792                        NaN         NaN
#
# [8793 rows x 26 columns]

# %%
huh[(huh['label_atom_id']=='CA') & 
    (huh['gen_pos1'] != 0.0)]
# Out:
#        PDB group_PDB auth_asym_id label_asym_id  label_seq_id auth_seq_id  \
# 1782  6OIJ      ATOM            R             B            31          22
# 1789  6OIJ      ATOM            R             B            32          23
# 1803  6OIJ      ATOM            R             B            33          24
# 1808  6OIJ      ATOM            R             B            34          25
# 1815  6OIJ      ATOM            R             B            35          26
# ...    ...       ...          ...           ...           ...         ...
# 3339  6OIJ      ATOM            R             B           230         221
# 3348  6OIJ      ATOM            R             B           231         222
# 3356  6OIJ      ATOM            R             B           232         223
# 3361  6OIJ      ATOM            R             B           233         224
# 3366  6OIJ      ATOM            R             B           234         225
#
#      label_comp_id    id label_atom_id type_symbol  ...  identifier  \
# 1782           PRO  1783            CA           C  ...  ACM1_HUMAN
# 1789           TRP  1790            CA           C  ...  ACM1_HUMAN
# 1803           GLN  1804            CA           C  ...  ACM1_HUMAN
# 1808           VAL  1809            CA           C  ...  ACM1_HUMAN
# 1815           ALA  1816            CA           C  ...  ACM1_HUMAN
# ...            ...   ...           ...         ...  ...         ...
# 3339           GLU  3340            CA           C  ...  ACM1_HUMAN
# 3348           LEU  3349            CA           C  ...  ACM1_HUMAN
# 3356           ALA  3357            CA           C  ...  ACM1_HUMAN
# 3361           ALA  3362            CA           C  ...  ACM1_HUMAN
# 3366           LEU  3367            CA           C  ...  ACM1_HUMAN
#
#      label_comp_sid label_2_uni  gen_pos  uniprot_comp_sid  gen_pos1 gen_pos2  \
# 1782              P        22.0  1.29x29                 P      1.29       29
# 1789              W        23.0  1.30x30                 W      1.30       30
# 1803              Q        24.0  1.31x31                 Q      1.31       31
# 1808              V        25.0  1.32x32                 V      1.32       32
# 1815              A        26.0  1.33x33                 A      1.33       33
# ...             ...         ...      ...               ...       ...      ...
# 3339              E       221.0  5.71x71                 E      5.71       71
# 3348              L       222.0  5.72x72                 L      5.72       72
# 3356              A       223.0  5.73x73                 A      5.73       73
# 3361              A       224.0  5.74x74                 A      5.74       74
# 3366              L       225.0  5.75x75                 L      5.75       75
#
#      gprot_pos  uniprot_comp_id fam_comp_id
# 1782                        NaN         NaN
# 1789                        NaN         NaN
# 1803                        NaN         NaN
# 1808                        NaN         NaN
# 1815                        NaN         NaN
# ...        ...              ...         ...
# 3339                        NaN         NaN
# 3348                        NaN         NaN
# 3356                        NaN         NaN
# 3361                        NaN         NaN
# 3366                        NaN         NaN
#
# [192 rows x 26 columns]

# %%
import numpy as np

# %%
section = 'H5'
poi =  'G.H5.23', 3.50
start = 3.40
end = 3.53

def dists_to_frame(pdb_id, dists, col_x, col_y):
    df = pd.DataFrame(dists, columns = col_x)
    return df.set_index([col_y])


l = [filtered_indices_gio, filtered_indices_gs, filtered_indices_q11]


def make_interaction_table(l, section='H5', poi=('G.H5.23', 3.50), start=3.40, end=3.53):
    if not isinstance(l, list):
        l = list(l)
    list_dists_df_list = []
    list_poi_list = []

    for i in range(len(l)):
        dists_df_list = []
        poi_list = []
        for j in range(len(l[i])):
            ex = p.dfl[l[i][j]]
            if 'gprot_pos' in ex.columns:
                pdb_id = ex['PDB'].iloc[0]
                col_x = ex[(ex['gen_pos1'] > start) & 
                           (ex['gen_pos1'] < end)&
                           (ex['label_atom_id'] == 'CA')]['gen_pos1'].to_list()
                r = ex[(ex['gen_pos1'] > start) &
                       (ex['gen_pos1'] < end) &
                       (ex['label_atom_id'] == 'CA')][['Cartn_x', 'Cartn_y', 'Cartn_z']].to_numpy()
                col_y = ex[(ex['gprot_pos'].str.contains(section)) &
                           (ex['label_atom_id'] == 'CA')]['gprot_pos'].to_list()
                g = ex[(ex['gprot_pos'].str.contains(section)) &
                           (ex['label_atom_id'] == 'CA')][['Cartn_x', 'Cartn_y', 'Cartn_z']].to_numpy()
                r=r.astype(float)
                g=g.astype(float)
                dists = cdist(r, g).T
                dist_df = dists_to_frame(pdb_id, dists, col_x, col_y)
                if (poi[1] in col_x) & (poi[0] in col_y):
                    poi_value = dist_df.loc[poi]
                else:
                    poi_value = np.nan
                if (len(col_x) > 0) & (len(col_y) > 0):
                    dists_df_list.append((pdb_id, i, dist_df))
                if poi_value != np.nan:
                    poi_list.append((pdb_id, i, poi_value))
        list_dists_df_list.append(dists_df_list)
        list_poi_list.append(poi_list)
    return list_poi_list, list_dists_df_list

# %%
list_poi_list, list_dists_df_list = make_interaction_table(l)

# %%
poi_gio = [x for x in list_poi_list[0] if ((x[1] == 0) & (x[2] > 0))]
poi_gs = [x for x in list_poi_list[1] if ((x[1] == 1) & (x[2] > 0))]
poi_q11 = [x for x in list_poi_list[2] if ((x[1] == 2) & (x[2] > 0))]

# %%
len(poi_gio) + len(poi_gs) + len(poi_q11)
# Out:
# 41

# %%
poi_gio_arr = np.asarray(poi_gio)[:, 2].astype(float)
poi_gs_arr = np.asarray(poi_gs)[:, 2].astype(float)

# %%
with open('gq11_350_h523.txt', 'w') as f:
    f.write(str(poi_q11))
with open('gs_350_h523.txt', 'w') as f:
    f.write(str(poi_gs))
with open('gio_350_h523.txt', 'w') as f:
    f.write(str(poi_gio))

# %%
poi_gio_arr
# Out:
# array([5.33238418, 6.53466219, 6.81318406, 6.85574015, 7.62350228,
#        8.272283  , 6.3359663 , 7.09809615, 7.11550237, 7.55777712,
#        7.19972506, 6.78437882, 7.44929279, 6.27346499, 6.8038578 ,
#        6.36703848, 7.63524374, 6.50693545, 8.67607947, 6.91676355,
#        7.45710145, 7.44929279, 6.50514181, 6.45559401, 6.0696219 ,
#        6.0693699 , 6.45559401])

# %%
poi_q11
# Out:
# [('6OIJ', 2, 8.139901780734213)]

# %%
if len(poi_q11) == 0:
    poi_q11_arr = np.nan
else:
    poi_q11_arr = np.asarray(poi_q11)[:, 2].astype(float)

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(['Gi/o', 'Gs', 'Gq11'])
y = [np.mean(poi_gio_arr), np.mean(poi_gs_arr), np.mean(poi_q11_arr)]
e = np.array([np.std(poi_gio_arr), np.std(poi_gs_arr), np.std(poi_q11_arr)])
plt.errorbar(x, y, e, linestyle='None', fmt='-o')
plt.show()

# %%
def get_cell(dataframe, row_idx, col_idx):
    if (row_idx in dataframe.index.to_list()) & (col_idx in dataframe.columns.to_list()):
        return dataframe.loc[row_idx, col_idx].astype(float)
    else:
        return None

# %%
def make_overview_df(dists_df_list):
    cols = []
    rows = []
    for i in range(len(dists_df_list)):
        l = dists_df_list[i]
        df = l[2]
        g_ind = df.index.to_list()
        r_ind = df.columns.to_list()
        cols = list(set(cols + r_ind))
        rows = list(set(rows + g_ind))
    occ_df = pd.DataFrame(index=rows, columns=cols)
    mean_df = pd.DataFrame(index=rows, columns=cols)
    std_df = pd.DataFrame(index=rows, columns=cols)
    for i in range(len(rows)):
        for j in range(len(cols)):
            val_list = []
            row_idx = rows[i]
            col_idx = cols[j]
            for k in range(len(dists_df_list)):
                df = dists_df_list[k][2]
                val = get_cell(df, row_idx, col_idx)
                if type(val) == pd.core.series.Series:
                    val = val.iloc[0]
                if val != None:
                    val_list.append(val)
            occ_df.loc[row_idx, col_idx] = len(val_list)
            mean_df.loc[row_idx, col_idx] = np.mean(val_list)
            std_df.loc[row_idx, col_idx] = np.std(val_list)
    occ_df = occ_df.sort_index().reindex(sorted(occ_df.columns), axis=1).astype(int)
    mean_df = mean_df.sort_index().reindex(sorted(mean_df.columns), axis=1).astype(float)
    std_df = std_df.sort_index().reindex(sorted(std_df.columns), axis=1).astype(float)
    return occ_df, mean_df, std_df

# %%
occ_df, mean_df, std_df = make_overview_df(list_dists_df_list[0])

# %%
def make_overview_plots(df, title='Occurances', cl='A', gprot='Gs', figsize=(20, 15), path='plots/', show=True, save=False):
    name = title + '_' + cl + '_' + gprot
    rcParams['figure.figsize'] = 20, 15
    ax = sns.heatmap(df, cmap='RdYlGn_r', linewidths=.1, annot=True)
    ax.set_title(title + ' ' + cl + ' ' + gprot)
    if show:
        ax.plot()
    if save:
        ax.figure.savefig(path+name+'.png')

# %%
make_overview_plots(occ_df, title='Occurances', cl='A', gprot='Gio', save=True)

# %%
make_overview_plots(mean_df, title='Mean', cl='A', gprot='Gio', save=True)

# %%
make_overview_plots(std_df, title='Std', cl='A', gprot='Gio', save=True)

# %%
occ_df, mean_df, std_df = make_overview_df(list_dists_df_list[1])

# %%
make_overview_plots(occ_df, title='Occurances', cl='A', gprot='Gs', save=True)

# %%
make_overview_plots(mean_df, title='Mean', cl='A', gprot='Gs', save=True)

# %%
make_overview_plots(std_df, title='Std', cl='A', gprot='Gs', save=True)

# %%
occ_df, mean_df, std_df = make_overview_df(list_dists_df_list[2])

# %%
make_overview_plots(occ_df, title='Occurances', cl='A', gprot='Gq11', save=True)

# %%
make_overview_plots(mean_df, title='Mean', cl='A', gprot='Gq11', save=True)

# %%
make_overview_plots(std_df, title='Std', cl='A', gprot='Gq11', save=True)
