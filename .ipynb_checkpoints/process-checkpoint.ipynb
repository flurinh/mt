# %%
from processor import *

# %%
p = CifProcessor()

# %%
p.get_metatable()

# %%
p.read_pkl_metainfo()

# %%
p.read_pkl_processed()

# %%
f = p.filter_dfl_via_table(State='Active', gprotein=True)

# %%
p.assign_generic_numbers_g(pdb_ids=None, overwrite=True, f = f, folder = 'data/raw/')
# Out:
#   0%|                                                                                                                                                                                                                                                                                           | 0/13 [00:00<?, ?it/s]
# Downloading uniprot gprotein sequences...
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 13/13 [00:21<00:00,  1.62s/it]
#  45%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍                                                                                                                                                      | 48/107 [00:40<00:57,  1.03it/s]
# Did not find label_seq_ids
#  50%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏                                                                                                                                         | 53/107 [00:44<00:42,  1.28it/s]
# Did not find label_seq_ids
#  73%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████                                                                          | 78/107 [01:01<00:17,  1.70it/s]
# Did not find label_seq_ids
#  86%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▋                                      | 92/107 [01:12<00:12,  1.24it/s]
# Did not find label_seq_ids
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 107/107 [01:20<00:00,  1.33it/s]

# %%
active_complexes_indices = p.get_dfl_indices(list(f['PDB']))

# %%
eg = active_complexes_indices[4]

# %%
ex = p.dfl[eg]

# %%
ex
# Out:
#        PDB group_PDB auth_asym_id label_asym_id  label_seq_id auth_seq_id  \
# 0     6NBH      ATOM            R             A             5          31
# 1     6NBH      ATOM            R             A             5          31
# 2     6NBH      ATOM            R             A             5          31
# 3     6NBH      ATOM            R             A             5          31
# 4     6NBH      ATOM            R             A             5          31
# ...    ...       ...          ...           ...           ...         ...
# 9247  6NBH      ATOM            N             F           126         126
# 9248  6NBH      ATOM            N             F           126         126
# 9249  6NBH      ATOM            N             F           126         126
# 9250  6NBH      ATOM            N             F           126         126
# 9251  6NBH      ATOM            N             F           126         126
#
#      label_comp_id    id label_atom_id type_symbol  ...   identifier  \
# 0              VAL     1             N           N  ...  PTH1R_HUMAN
# 1              VAL     2            CA           C  ...  PTH1R_HUMAN
# 2              VAL     3             C           C  ...  PTH1R_HUMAN
# 3              VAL     4             O           O  ...  PTH1R_HUMAN
# 4              VAL     5            CB           C  ...  PTH1R_HUMAN
# ...            ...   ...           ...         ...  ...          ...
# 9247           VAL  9248             C           C  ...  PTH1R_HUMAN
# 9248           VAL  9249             O           O  ...  PTH1R_HUMAN
# 9249           VAL  9250            CB           C  ...  PTH1R_HUMAN
# 9250           VAL  9251           CG1           C  ...  PTH1R_HUMAN
# 9251           VAL  9252           CG2           C  ...  PTH1R_HUMAN
#
#      label_comp_sid label_2_uni  gen_pos  uniprot_comp_sid  gen_pos1 gen_pos2  \
# 0                 V         NaN                                  0.0        0
# 1                 V        31.0                                  0.0        0
# 2                 V         NaN                                  0.0        0
# 3                 V         NaN                                  0.0        0
# 4                 V         NaN                                  0.0        0
# ...             ...         ...      ...               ...       ...      ...
# 9247              V         NaN                                  0.0        0
# 9248              V         NaN                                  0.0        0
# 9249              V         NaN                                  0.0        0
# 9250              V         NaN                                  0.0        0
# 9251              V         NaN                                  0.0        0
#
#      gprot_pos  uniprot_comp_id fam_comp_id
# 0                           NaN         NaN
# 1                           NaN         NaN
# 2                           NaN         NaN
# 3                           NaN         NaN
# 4                           NaN         NaN
# ...        ...              ...         ...
# 9247                        NaN         NaN
# 9248                        NaN         NaN
# 9249                        NaN         NaN
# 9250                        NaN         NaN
# 9251                        NaN         NaN
#
# [9252 rows x 26 columns]

# %%
ex[ex['gprot_pos'] != '']
# Out:
#        PDB group_PDB auth_asym_id label_asym_id  label_seq_id auth_seq_id  \
# 3382  6NBH      ATOM            A             C            11          11
# 3390  6NBH      ATOM            A             C            12          12
# 3399  6NBH      ATOM            A             C            13          13
# 3410  6NBH      ATOM            A             C            14          14
# 3418  6NBH      ATOM            A             C            15          15
# ...    ...       ...          ...           ...           ...         ...
# 5197  6NBH      ATOM            A             C           373         389
# 5208  6NBH      ATOM            A             C           374         390
# 5217  6NBH      ATOM            A             C           375         391
# 5229  6NBH      ATOM            A             C           376         392
# 5238  6NBH      ATOM            A             C           377         393
#
#      label_comp_id    id label_atom_id type_symbol  ...   identifier  \
# 3382           ASP  3383            CA           C  ...  PTH1R_HUMAN
# 3390           GLN  3391            CA           C  ...  PTH1R_HUMAN
# 3399           ARG  3400            CA           C  ...  PTH1R_HUMAN
# 3410           ASN  3411            CA           C  ...  PTH1R_HUMAN
# 3418           GLU  3419            CA           C  ...  PTH1R_HUMAN
# ...            ...   ...           ...         ...  ...          ...
# 5197           ARG  5198            CA           C  ...  PTH1R_HUMAN
# 5208           GLN  5209            CA           C  ...  PTH1R_HUMAN
# 5217           TYR  5218            CA           C  ...  PTH1R_HUMAN
# 5229           GLU  5230            CA           C  ...  PTH1R_HUMAN
# 5238           LEU  5239            CA           C  ...  PTH1R_HUMAN
#
#      label_comp_sid label_2_uni  gen_pos  uniprot_comp_sid  gen_pos1 gen_pos2  \
# 3382              D        11.0                                  0.0        0
# 3390              Q        12.0                                  0.0        0
# 3399              R        13.0                                  0.0        0
# 3410              N        14.0                                  0.0        0
# 3418              E        15.0                                  0.0        0
# ...             ...         ...      ...               ...       ...      ...
# 5197              R       389.0                                  0.0        0
# 5208              Q       390.0                                  0.0        0
# 5217              Y       391.0                                  0.0        0
# 5229              E       392.0                                  0.0        0
# 5238              L       393.0                                  0.0        0
#
#      gprot_pos  uniprot_comp_id fam_comp_id
# 3382   G.HN.28                D           D
# 3390   G.HN.29                Q           Q
# 3399   G.HN.30                R           R
# 3410   G.HN.31                N           N
# 3418   G.HN.32                E           E
# ...        ...              ...         ...
# 5197   G.H5.21                R           R
# 5208   G.H5.22                Q           Q
# 5217   G.H5.23                Y           Y
# 5229   G.H5.24                E           E
# 5238   G.H5.25                L           L
#
# [223 rows x 26 columns]
