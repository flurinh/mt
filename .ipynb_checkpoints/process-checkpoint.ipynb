# %%
from processor import *
from scipy.spatial.distance import cdist, pdist
import seaborn as sns
from matplotlib import rcParams

# %%
p = CifProcessor()

# %%
p.get_metatable()

# %%
p.read_pkl_metainfo()

# %%
p.read_pkl_processed()

# %%
p.table['Family'].unique()
# Out:
# array(['GPa1family', '-', 'Gi/o', 'Gs', 'Beta', 'Gq/11', 'Visual'],
#       dtype=object)

# %%
f = p.filter_dfl_via_table(State='Active', gprotein=True)

# %%
p.assign_generic_numbers_g(pdb_ids=None, overwrite=True, f = f, folder = 'data/raw/')
# Out:
#   0%|                                                                                                                                                                                                              | 0/13 [00:00<?, ?it/s]
# Downloading uniprot gprotein sequences...
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 13/13 [00:20<00:00,  1.57s/it]
#  45%|███████████████████████████████████████████████████████████████████████████████████████▉                                                                                                            | 48/107 [01:16<01:58,  2.01s/it]
# Did not find label_seq_ids
#  50%|█████████████████████████████████████████████████████████████████████████████████████████████████                                                                                                   | 53/107 [01:23<01:30,  1.68s/it]
# Did not find label_seq_ids
#  73%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉                                                     | 78/107 [01:55<00:30,  1.05s/it]
# Did not find label_seq_ids
#  86%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌                           | 92/107 [02:14<00:21,  1.45s/it]
# Did not find label_seq_ids
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 107/107 [02:30<00:00,  1.40s/it]

# %%
f_gio = p.filter_dfl_via_table(State='Active', Family='Gi/o', gprotein=True)

# %%
f_gs = p.filter_dfl_via_table(State='Active', Family='Gs', gprotein=True)

# %%
f_q11 = p.filter_dfl_via_table(State='Active', Family='Gq/11', gprotein=True)

# %%
filtered_indices_gio = [x for x in p.get_dfl_indices(list(f_gio['PDB'])) if x != None]

# %%
filtered_indices_gs = [x for x in p.get_dfl_indices(list(f_gs['PDB'])) if x != None]

# %%
filtered_indices_q11 = [x for x in p.get_dfl_indices(list(f_q11['PDB'])) if x != None]

# %%
filtered_indices_q11
# Out:
# [382, 462]

# %%
huh = p.dfl[382]

# %%
huh[(huh['label_atom_comp_id'])]

# %%
import numpy as np

# %%
section = 'H5'
poi =  'G.H5.23', 3.50
start = 3.40
end = 3.53

def dists_to_frame(pdb_id, dists, col_x, col_y):
    df = pd.DataFrame(dists, columns = col_x)
    return df.set_index([col_y])


l = [filtered_indices_gio, filtered_indices_gs, filtered_indices_q11]

dists_df_list = []
poi_list = []

for i in range(3):
    for j in range(len(l[i])):
        ex = p.dfl[l[i][j]]
        if 'gprot_pos' in ex.columns:
            pdb_id = ex['PDB'].iloc[0]
            
            col_x = ex[(ex['gen_pos1'] > start) & 
                       (ex['gen_pos1'] < end)&
                       (ex['label_atom_id'] == 'CA')]['gen_pos1'].to_list()
            r = ex[(ex['gen_pos1'] > start) &
                   (ex['gen_pos1'] < end) &
                   (ex['label_atom_id'] == 'CA')][['Cartn_x', 'Cartn_y', 'Cartn_z']].to_numpy()
            
            col_y = ex[(ex['gprot_pos'].str.contains(section)) &
                       (ex['label_atom_id'] == 'CA')]['gprot_pos'].to_list()
            g = ex[(ex['gprot_pos'].str.contains(section)) &
                       (ex['label_atom_id'] == 'CA')][['Cartn_x', 'Cartn_y', 'Cartn_z']].to_numpy()
            r=r.astype(float)
            g=g.astype(float)
            
            dists = cdist(r, g).T
            
            dist_df = dists_to_frame(pdb_id, dists, col_x, col_y)

            if (poi[1] in col_x) & (poi[0] in col_y):
                poi_value = dist_df.loc[poi]
            else:
                poi_value = np.nan
            if (len(col_x) > 0) & (len(col_y) > 0):
                dists_df_list.append((pdb_id, i, dist_df))
            if poi_value != np.nan:
                poi_list.append((pdb_id, i, poi_value))

# %%
poi_gio = [x for x in poi_list if ((x[1] == 0) & (x[2] > 0))]
poi_gs = [x for x in poi_list if ((x[1] == 1) & (x[2] > 0))]
poi_q11 = [x for x in poi_list if ((x[1] == 2) & (x[2] > 0))]

# %%
poi_gio_arr = np.asarray(poi_gio)[:, 2].astype(float)
poi_gs_arr = np.asarray(poi_gs)[:, 2].astype(float)

# %%
with open('gq11_350_h523.txt', 'w') as f:
    f.write(str(poi_q11))

# %%
poi_gio_arr
# Out:
# array([ 5.33238418,  6.53466219,  6.81318406,  6.85574015,  7.62350228,
#         8.272283  ,  6.3359663 ,  7.09809615,  7.11550237,  7.55777712,
#         7.19972506,  6.78437882,  7.02594485,  6.64239392,  6.9580406 ,
#         7.2655421 , 11.73400737, 11.59864393,  8.8039001 ,  6.8038578 ,
#         6.36703848,  7.63524374,  6.50693545, 11.16532333,  8.36443124,
#         6.91676355,  7.45710145,  7.44929279, 11.75676928,  6.50693545,
#         6.45559401,  6.0696219 ,  6.0693699 ,  6.45559401])

# %%
poi_q11
# Out:
# [('6OIJ', 2, 8.139901780734213)]

# %%
if len(poi_q11) == 0:
    poi_q11_arr = np.nan
else:
    poi_q11_arr = np.asarray(poi_q11)[:, 2].astype(float)

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(['Gi/o', 'Gs', 'Gq11'])
y = [np.mean(poi_gio_arr), np.mean(poi_gs_arr), np.mean(poi_q11_arr)]
e = np.array([np.std(poi_gio_arr), np.std(poi_gs_arr), np.std(poi_q11_arr)])
plt.errorbar(x, y, e, linestyle='None', fmt='-o')
plt.show()

# %%
poi_q11_arr
# Out:
# array([8.13990178])

# %%
mean_dfs = []


for j in range(3):
    for i in range(len(dists_df_list)):
        if dists_df_list[i][1] == j:
            df = dists_df_list[i][2] / len(l[j])
            if i == 0:
                df_stack = df
            else:
                df_stack = df_stack.add(df, fill_value=0)
    mean_dfs.append(df_stack)

# %%
# figure size in inches
rcParams['figure.figsize'] = 20, 15

sns.heatmap(mean_dfs[0], cmap='RdYlGn_r', linewidths=.1, annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(mean_dfs[1], cmap='RdYlGn_r', linewidths=.1, annot=True)
# Out:
# <AxesSubplot:>

# %%
poi = 3.50, 'G.H5.23'

# %%
dist_df.loc[poi]
# Out:
# 6.784378821970364
