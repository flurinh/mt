# %%
from utils import *
from utils2 import *
from utils3 import *

# %%
import pandas as pd
from tqdm import tqdm
from os import walk

from Bio.PDB import PDBParser

# %%
PATH = 'data/pdb/active/'

# %%
def get_pdb_files(path=PATH):
    _, _, filenames = next(walk(path))
    return [x for x in filenames if '.pdb' in x]

# %%
def load_pdb(name, path=PATH):
    """
    Load Pdb and get for each atom xyz-coordinates, Atom type (CA, H, N, NZ etc.) and Residue type (ALA, PRO etc.)
    """
    p = PDBParser()
    structure = p.get_structure(name, path + name)
    types = []
    xyz = []
    res = []
    atoms = []
    model = structure[0]
    for chain in model:
        for residue in chain:
            res.append([residue.get_resname(), str(residue.get_id()[1]).zfill(3)])
            atoms_ = []
            for atom in residue:
                atoms_.append([atom.get_coord(), atom.get_id()])
            atoms.append(atoms_)
    return res, atoms

# %%
# res, atoms = load_pdb(filenames[0])

# %%
def map_gaps(x):
    min_num = 0
    gaps = []
    for i, z in enumerate(x):
        new_num = int(z[0][1])
        if not abs(new_num - min_num) <= 1:
            gaps.append((i, min_num, new_num))
            min_num = new_num
        else:
            min_num += 1
    return gaps

# %%
#map_gaps(zip(res, atoms))

# %%
from gpcrdb_soup import *

# %%
class Download():
    def __init__(self, 
                 path='data/'):
        self.path_pdb = path + 'pdb/'
        self.path_alignment = path + 'alignments/'
        self.path_table = 'gpcrdb/'
        
        self.table = None
        self.filenames, self.pdb_ids = get_pdb_files(path=self.path_pdb)
    
    # ======================================================================================================================
        
    def download_alignment(self):
        print("Not Implemented! TBD manually.")
    
    def download_pdbs(self, reload=False, update=False):
        pdb_table_ids = self.table['PDB'].tolist()
        missing = [x for x in pdb_table_ids if x not in self.pdb_ids]
        if reload or (len(missing)>0):
            print("Reloading pdb files...")
            print("Missing pdbs:", missing)
            fileformat='mmcif'
            for pdb in tqdm(missing):
                url = get_rcsb_download(pdb, fileformat)
                download_pdb(url, folder=self.path_pdb, fileformat=fileformat)
        elif update:
            self.update_pdbs()
        self.filenames, self.pdb_ids = get_pdb_files(path=self.path_pdb)
                
    def download_table(self, reload=True, filename='structure.pkl'):
        table_path = self.path_table + filename
        if reload or (not os.path.isfile(self.path_table+filename)):
            self. table = get_table(reload=True, uniprot=False)
        else:
            self.table = get_table(reload=False, uniprot=False)
            self.table = self.table[self.table['Species'].str.contains('Human')]
        self.table = self.table.drop(columns=['filler', 'filler2', 'receptor family', 
                                              'Species', 'Method', 'Refined Structure', 'Degree active %', 
                                              '% of Seq1', 'Family', 'Subtype', 'Name2', 'Fusion', 'Note', 
                                              '% of Seq2', 'Antibodies', 'Name1', 'Type1', 'Type2', 
                                              'D2x50 - S3x39', 'Sodium in structure', 'Authors', 'Reference', 
                                              'PDB date', 'Annotated', 'pdb_link'])
        
    # ======================================================================================================================
    
    def update_pdbs(self):
        updatepdbs(self.path_pdb)
    
    # ======================================================================================================================
    
    def preprocess(self):
        # drop unimportant 
        pass

# %%
D = Download()

# %%
D.download_alignment()
# Out:
# Not Implemented! TBD manually.

# %%
print(D.table)
# Out:
# None

# %%
D.download_table(reload=False)

# %%
D.table
# Out:
#     uniprot(gene)                           Cl.   PDB  Resolution  \
# 0            STE2  D1(Ste2-likefungalpheromone)  7AD3         3.5
# 1            CCR2                  A(Rhodopsin)  5T1A         2.8
# 2            OPRM                  A(Rhodopsin)  4DKL         2.8
# 3            CNR2                  A(Rhodopsin)  5ZTY         2.8
# 4           5HT1B                  A(Rhodopsin)  6G79         3.8
# ..            ...                           ...   ...         ...
# 523          OPSD                  A(Rhodopsin)  6PH7         2.9
# 524          NTR1                  A(Rhodopsin)  7L0S         4.5
# 525         AA2AR                  A(Rhodopsin)  6S0Q         2.7
# 526         GLP1R                  B1(Secretin)  7LCJ         2.8
# 527          NTR1                  A(Rhodopsin)  7L0Q         4.3
#
#     Preferred Chain     State       Function
# 0                 A    Active        Agonist
# 1                 A  Inactive  AntagonistNAM
# 2                 A  Inactive     Antagonist
# 3                 A  Inactive     Antagonist
# 4                 S    Active        Agonist
# ..              ...       ...            ...
# 523               A    Active        unknown
# 524               C    Active        Agonist
# 525               A  Inactive     Antagonist
# 526               R    Active        Agonist
# 527               C    Active        Agonist
#
# [528 rows x 7 columns]

# %%
D.download_pdbs(reload=True)
# Out:
#   0%|                                                                                                                                                                                                                                                                                          | 0/528 [00:00<?, ?it/s]
# Reloading pdb files...
# Missing pdbs: ['7AD3', '5T1A', '4DKL', '5ZTY', '6G79', '6TPK', '6K42', '6K41', '7KNU', '7KNT', '6AK3', '5XSZ', '6LFM', '6LFL', '6LFO', '1GZM', '5NDD', '5NJ6', '5NDZ', '4N6H', '6OSA', '6OS9', '6CM4', '4OO9', '6NBF', '6NBI', '6NBH', '3VGA', '3VG9', '5JQH', '5YC8', '5ZKC', '5ZKB', '5ZK8', '5ZK3', '5O9H', '6WWZ', '6A93', '6A94', '7JV5', '7JVQ', '7JVP', '7JVR', '6RNK', '6IBB', '5TGZ', '5ZHP', '6PB0', '6PB1', '3OE8', '3ODU', '3OE6', '3OE9', '3OE0', '5C1M', '4MQT', '4MQS', '4XNV', '4XNW', '4UG2', '4UHR', '6U1N', '4AMJ', '4AMI', '6ME4', '6ME2', '6ME5', '6ME3', '6W2Y', '6W2X', '5WQC', '5WS3', '6QZH', '6OFJ', '6RZ8', '6RZ6', '6RZ9', '6RZ7', '7D77', '7D76', '5L7D', '5L7I', '6PWC', '5XEZ', '5XF1', '3RZE', '5VEW', '5VEX', '6OIJ', '6OIK', '7CZ5', '4Z36', '4Z34', '4Z35', '4Z9G', '5WIU', '5WIV', '3PBL', '6B73', '3VW7', '5ZKP', '5ZKQ', '4IAQ', '4IAR', '6W25', '6UO9', '6UOA', '6UO8', '6VJM', '6LI2', '6LI3', '6LI0', '6LI1', '6H7N', '6IBL', '4ZWJ', '6OL9', '5XPR', '5X93', '4ZUD', '3V2Y', '3V2W', '6PT0', '6HLO', '6HLL', '6HLP', '6BD4', '6RZ4', '6RZ5', '4BUO', '4BV0', '4BWB', '3ZEV', '5YHL', '5YWY', '4IB4', '6JOD', '7CFM', '7CFN', '6WPW', '6N4B', '5LWE', '5VBL', '6TOD', '6TPJ', '6TP3', '6TP4', '6TPG', '6TOS', '6TQ6', '6TO7', '6TQ9', '6TQ7', '6TPN', '6TP6', '6TQ4', '6TOT', '5G53', '6WI9', '6WZG', '5UEN', '6WGT', '6WHA', '6WH4', '6M9T', '5DHH', '5DHG', '5NX2', '5TUD', '5UIW', '6VI4', '7C7S', '7C7Q', '6P9X', '6P9Y', '4NTJ', '6IIV', '6IIU', '6VN7', '6X18', '6X1A', '6X19', '4OR2', '6BQG', '6BQH', '6FJ3', '6KP6', '5WB1', '5WB2', '6WJC', '5ZBH', '5ZBQ', '6PT3', '6PT2', '5TZR', '5TZY', '6D9H', '6NIY', '6UVA', '6UUN', '6UUS', '6XBJ', '6XBL', '6XBK', '6XBM', '3SN6', '2YDO', '2YDV', '6B3J', '6D26', '6D27', '5X33', '4QIM', '4N4W', '4QIN', '2I36', '2I35', '2I37', '2X72', '5F8U', '5GLH', '5GLI', '6PS1', '6PS4', '6PS3', '6PS6', '6PS5', '6PS2', '6PS7', '6PS8', '6PS0', '6GDG', '4ZJ8', '4ZJC', '6TKO', '5OLZ', '5OLH', '5OM1', '5OLO', '5OLV', '5OM4', '5OLG', '6LUQ', '4RWD', '4RWA', '6I9K', '7BW0', '5K2C', '5K2D', '5K2B', '5K2A', '5U09', '6E3Y', '3C9M', '3C9L', '3PXO', '3PQR', '3ZPR', '3ZPQ', '3NYA', '3NY9', '3NY8', '5D6L', '4QKX', '5IUA', '5IU8', '5IU7', '5IUB', '5IU4', '4EA3', '3REY', '3RFM', '3PWH', '5UIG', '1L9H', '5UNG', '5UNF', '5UNH', '4U16', '4U15', '4U14', '7D3S', '1HZX', '2Y01', '2Y02', '2Y03', '2Y04', '2Y00', '6J20', '6J21', '5A8E', '6DRZ', '6DRY', '6DS0', '6DRX', '6KJV', '6KK7', '6KK1', '4J4Q', '4S0V', '4LDE', '4LDO', '4LDL', '6FFI', '6FFH', '3CAP', '6LPB', '6KPF', '6KPC', '6KPG', '4PHU', '5JTB', '5V57', '5V56', '6N48', '5EE7', '6AKY', '6AKX', '5W0P', '6K1Q', '4GBR', '1U19', '3UZA', '3UZC', '3UON', '6LPL', '6LPK', '6LPJ', '5DGY', '5N2R', '5N2S', '5MZP', '5MZJ', '6D32', '6D35', '4GPO', '7CKZ', '7CKX', '7CKW', '7CRH', '7CKY', '5NLX', '5NM2', '5NM4', '6ZDV', '6ZDR', '6H7O', '6H7M', '6H7L', '6H7J', '6IQL', '2VT4', '2YCY', '2YCX', '2YCW', '2YCZ', '4PY0', '4PXZ', '2R4S', '2R4R', '6C1R', '6C1Q', '3QAK', '6UP7', '4K5Y', '6OMM', '5XR8', '5XRA', '6VCB', '6V9S', '3AYM', '3AYN', '4RWS', '6KNM', '6OS2', '6OS1', '6OS0', '2RH1', '6FKC', '6FK6', '6FKB', '6FK7', '6FKD', '6FK8', '6FKA', '6FK9', '6N51', '6N52', '6E67', '5DSG', '5CXV', '4DAJ', '6LW5', '6ME8', '6ME6', '6ME9', '6ME7', '7CA3', '7CUM', '7CA5', '6WQA', '5DYS', '5EN0', '6LN2', '6M1I', '6M1H', '6OYA', '6OY9', '7JJO', '4L6R', '4DJH', '4PXF', '4X1H', '6GPS', '6GPX', '5TVN', '6VMS', '7LJC', '7LJD', '5UZ7', '4EJ4', '4BVN', '6WHC', '4A4M', '5D5A', '5D5B', '7DFP', '2ZIY', '5TE5', '5TE3', '6Z10', '3DQB', '4GRV', '6DO1', '6MH8', '4NC3', '5CGC', '5CGD', '6KQI', '3D4S', '4XT3', '4XT1', '6XOX', '3PDS', '5VRA', '5WKT', '2Z73', '6LRY', '2G87', '7BZ2', '6OT0', '6WW2', '6JZH', '6OBA', '6AQF', '5UVI', '7C6A', '7C61', '6O3C', '2J4Y', '5X7D', '5WF6', '5WF5', '5T04', '6DDF', '6DDE', '5XJM', '6E59', '4WW3', '3KJ6', '4EIY', '3EML', '5VAI', '5YQZ', '6CMO', '6LMK', '6LML', '1F88', '6FUF', '2PED', '4YAY', '7DHI', '7DHR', '4BEZ', '4BEY', '5KW2', '6IGK', '6IGL', '4JKV', '6MXT', '2HPY', '6QNO', '4XES', '4XEE', '4O9R', '6MET', '6MEO', '6WIV', ' ...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-486b38abe738> in <module>
# ----> 1 D.download_pdbs(reload=True)
#
# <ipython-input-12-c64af789b67b> in download_pdbs(self, reload, update)
#      22             for pdb in tqdm(missing):
#      23                 url = get_rcsb_download(pdb, fileformat='mmcif')
# ---> 24                 download_pdb(url, folder=self.path_pdb, fileformat=fileformat)
#      25         elif update:
#      26             self.update_pdbs()
#
# NameError: name 'fileformat' is not defined

# %%
D.filenames
# Out:
# ['data/pdb/00.m.pdb',
#  'data/pdb/01.m.pdb',
#  'data/pdb/02.m.pdb',
#  'data/pdb/03.m.pdb',
#  'data/pdb/04.m.pdb',
#  'data/pdb/09.m.pdb',
#  'data/pdb/0G.m.pdb',
#  'data/pdb/0L.m.pdb',
#  'data/pdb/0P.m.pdb',
#  'data/pdb/0Q.m.pdb',
#  'data/pdb/0R.m.pdb',
#  'data/pdb/0S.m.pdb',
#  'data/pdb/0V.m.pdb',
#  'data/pdb/10.m.pdb',
#  'data/pdb/14.m.pdb',
#  'data/pdb/15.m.pdb',
#  'data/pdb/16.m.pdb',
#  'data/pdb/18.m.pdb',
#  'data/pdb/19.m.pdb',
#  'data/pdb/1A.m.pdb',
#  'data/pdb/1H.m.pdb',
#  'data/pdb/1I.m.pdb',
#  'data/pdb/1M.m.pdb',
#  'data/pdb/1N.m.pdb',
#  'data/pdb/1Q.m.pdb',
#  'data/pdb/1R.m.pdb',
#  'data/pdb/20.m.pdb',
#  'data/pdb/21.m.pdb',
#  'data/pdb/25.m.pdb',
#  'data/pdb/26.m.pdb',
#  'data/pdb/27.m.pdb',
#  'data/pdb/2A.m.pdb',
#  'data/pdb/2B.m.pdb',
#  'data/pdb/2C.m.pdb',
#  'data/pdb/2D.m.pdb',
#  'data/pdb/2E.m.pdb',
#  'data/pdb/2R.m.pdb',
#  'data/pdb/2S.m.pdb',
#  'data/pdb/2W.m.pdb',
#  'data/pdb/2X.m.pdb',
#  'data/pdb/2Y.m.pdb',
#  'data/pdb/32.m.pdb',
#  'data/pdb/33.m.pdb',
#  'data/pdb/34.m.pdb',
#  'data/pdb/35.m.pdb',
#  'data/pdb/36.m.pdb',
#  'data/pdb/37.m.pdb',
#  'data/pdb/3C.m.pdb',
#  'data/pdb/3J.m.pdb',
#  'data/pdb/3S.m.pdb',
#  'data/pdb/3Y.m.pdb',
#  'data/pdb/41.m.pdb',
#  'data/pdb/42.m.pdb',
#  'data/pdb/48.m.pdb',
#  'data/pdb/4B.m.pdb',
#  'data/pdb/4M.m.pdb',
#  'data/pdb/4Q.m.pdb',
#  'data/pdb/4R.m.pdb',
#  'data/pdb/4S.m.pdb',
#  'data/pdb/4W.m.pdb',
#  'data/pdb/4Y.m.pdb',
#  'data/pdb/51.m.pdb',
#  'data/pdb/52.m.pdb',
#  'data/pdb/53.m.pdb',
#  'data/pdb/54.m.pdb',
#  'data/pdb/56.m.pdb',
#  'data/pdb/57.m.pdb',
#  'data/pdb/59.m.pdb',
#  'data/pdb/5A.m.pdb',
#  'data/pdb/5B.m.pdb',
#  'data/pdb/5Y.m.pdb',
#  'data/pdb/61.m.pdb',
#  'data/pdb/67.m.pdb',
#  'data/pdb/6A.m.pdb',
#  'data/pdb/6H.m.pdb',
#  'data/pdb/6L.m.pdb',
#  'data/pdb/6R.m.pdb',
#  'data/pdb/72.m.pdb',
#  'data/pdb/73.m.pdb',
#  'data/pdb/76.m.pdb',
#  'data/pdb/77.m.pdb',
#  'data/pdb/79.m.pdb',
#  'data/pdb/7D.m.pdb',
#  'data/pdb/7I.m.pdb',
#  'data/pdb/7J.m.pdb',
#  'data/pdb/7L.m.pdb',
#  'data/pdb/7M.m.pdb',
#  'data/pdb/7N.m.pdb',
#  'data/pdb/7O.m.pdb',
#  'data/pdb/7Q.m.pdb',
#  'data/pdb/7S.m.pdb',
#  'data/pdb/87.m.pdb',
#  'data/pdb/88.m.pdb',
#  'data/pdb/8E.m.pdb',
#  'data/pdb/8U.m.pdb',
#  'data/pdb/93.m.pdb',
#  'data/pdb/94.m.pdb',
#  'data/pdb/9G.m.pdb',
#  'data/pdb/9H.m.pdb',
#  'data/pdb/9K.m.pdb',
#  'data/pdb/9L.m.pdb',
#  'data/pdb/9M.m.pdb',
#  'data/pdb/9R.m.pdb',
#  'data/pdb/9S.m.pdb',
#  'data/pdb/9T.m.pdb',
#  'data/pdb/9X.m.pdb',
#  'data/pdb/9Y.m.pdb',
#  'data/pdb/A3.m.pdb',
#  'data/pdb/A5.m.pdb',
#  'data/pdb/AI.m.pdb',
#  'data/pdb/AJ.m.pdb',
#  'data/pdb/AK.m.pdb',
#  'data/pdb/AP.m.pdb',
#  'data/pdb/AQ.m.pdb',
#  'data/pdb/AR.m.pdb',
#  'data/pdb/AX.m.pdb',
#  'data/pdb/AY.m.pdb',
#  'data/pdb/B0.m.pdb',
#  'data/pdb/B1.m.pdb',
#  'data/pdb/B2.m.pdb',
#  'data/pdb/B4.m.pdb',
#  'data/pdb/BA.m.pdb',
#  'data/pdb/BB.m.pdb',
#  'data/pdb/BF.m.pdb',
#  'data/pdb/BH.m.pdb',
#  'data/pdb/BI.m.pdb',
#  'data/pdb/BJ.m.pdb',
#  'data/pdb/BK.m.pdb',
#  'data/pdb/BL.m.pdb',
#  'data/pdb/BM.m.pdb',
#  'data/pdb/BQ.m.pdb',
#  'data/pdb/BR.m.pdb',
#  'data/pdb/BS.m.pdb',
#  'data/pdb/C3.m.pdb',
#  'data/pdb/C8.m.pdb',
#  'data/pdb/CB.m.pdb',
#  'data/pdb/CI.m.pdb',
#  'data/pdb/CJ.m.pdb',
#  'data/pdb/CK.m.pdb',
#  'data/pdb/CW.m.pdb',
#  'data/pdb/CX.m.pdb',
#  'data/pdb/CY.m.pdb',
#  'data/pdb/CZ.m.pdb',
#  'data/pdb/D3.m.pdb',
#  'data/pdb/D4.m.pdb',
#  'data/pdb/DD.m.pdb',
#  'data/pdb/DE.m.pdb',
#  'data/pdb/DF.m.pdb',
#  'data/pdb/DG.m.pdb',
#  'data/pdb/DL.m.pdb',
#  'data/pdb/DO.m.pdb',
#  'data/pdb/DR.m.pdb',
#  'data/pdb/DS.m.pdb',
#  'data/pdb/DU.m.pdb',
#  'data/pdb/DV.m.pdb',
#  'data/pdb/DZ.m.pdb',
#  'data/pdb/E0.m.pdb',
#  'data/pdb/E2.m.pdb',
#  'data/pdb/E3.m.pdb',
#  'data/pdb/E4.m.pdb',
#  'data/pdb/E5.m.pdb',
#  'data/pdb/E6.m.pdb',
#  'data/pdb/E7.m.pdb',
#  'data/pdb/E8.m.pdb',
#  'data/pdb/E9.m.pdb',
#  'data/pdb/ED.m.pdb',
#  'data/pdb/EE.m.pdb',
#  'data/pdb/EL.m.pdb',
#  'data/pdb/EN.m.pdb',
#  'data/pdb/EO.m.pdb',
#  'data/pdb/ES.m.pdb',
#  'data/pdb/ET.m.pdb',
#  'data/pdb/EV.m.pdb',
#  'data/pdb/EW.m.pdb',
#  'data/pdb/EX.m.pdb',
#  'data/pdb/EY.m.pdb',
#  'data/pdb/EZ.m.pdb',
#  'data/pdb/F1.m.pdb',
#  'data/pdb/F5.m.pdb',
#  'data/pdb/F6.m.pdb',
#  'data/pdb/FH.m.pdb',
#  'data/pdb/FI.m.pdb',
#  'data/pdb/FJ.m.pdb',
#  'data/pdb/FL.m.pdb',
#  'data/pdb/FM.m.pdb',
#  'data/pdb/FN.m.pdb',
#  'data/pdb/FO.m.pdb',
#  'data/pdb/FP.m.pdb',
#  'data/pdb/G2.m.pdb',
#  'data/pdb/G9.m.pdb',
#  'data/pdb/GA.m.pdb',
#  'data/pdb/GC.m.pdb',
#  'data/pdb/GD.m.pdb',
#  'data/pdb/GK.m.pdb',
#  'data/pdb/GL.m.pdb',
#  'data/pdb/GS.m.pdb',
#  'data/pdb/GT.m.pdb',
#  'data/pdb/GY.m.pdb',
#  'data/pdb/GZ.m.pdb',
#  'data/pdb/H1.m.pdb',
#  'data/pdb/H4.m.pdb',
#  'data/pdb/H7.m.pdb',
#  'data/pdb/H8.m.pdb',
#  'data/pdb/HA.m.pdb',
#  'data/pdb/HC.m.pdb',
#  'data/pdb/HG.m.pdb',
#  'data/pdb/HH.m.pdb',
#  'data/pdb/HI.m.pdb',
#  'data/pdb/HL.m.pdb',
#  'data/pdb/HP.m.pdb',
#  'data/pdb/HR.m.pdb',
#  'data/pdb/HU.m.pdb',
#  'data/pdb/I0.m.pdb',
#  'data/pdb/I1.m.pdb',
#  'data/pdb/I2.m.pdb',
#  'data/pdb/I3.m.pdb',
#  'data/pdb/I4.m.pdb',
#  'data/pdb/I9.m.pdb',
#  'data/pdb/IG.m.pdb',
#  'data/pdb/IJ.m.pdb',
#  'data/pdb/IK.m.pdb',
#  'data/pdb/IM.m.pdb',
#  'data/pdb/IN.m.pdb',
#  'data/pdb/IU.m.pdb',
#  'data/pdb/IV.m.pdb',
#  'data/pdb/IW.m.pdb',
#  'data/pdb/IY.m.pdb',
#  'data/pdb/J3.m.pdb',
#  'data/pdb/J4.m.pdb',
#  'data/pdb/J6.m.pdb',
#  'data/pdb/J8.m.pdb',
#  'data/pdb/JC.m.pdb',
#  'data/pdb/JD.m.pdb',
#  'data/pdb/JH.m.pdb',
#  'data/pdb/JM.m.pdb',
#  'data/pdb/JO.m.pdb',
#  'data/pdb/JV.m.pdb',
#  'data/pdb/K1.m.pdb',
#  'data/pdb/K3.m.pdb',
#  'data/pdb/K6.m.pdb',
#  'data/pdb/K7.m.pdb',
#  'data/pdb/K8.m.pdb',
#  'data/pdb/K9.m.pdb',
#  'data/pdb/KA.m.pdb',
#  'data/pdb/KB.m.pdb',
#  'data/pdb/KC.m.pdb',
#  'data/pdb/KD.m.pdb',
#  'data/pdb/KL.m.pdb',
#  'data/pdb/KO.m.pdb',
#  'data/pdb/KP.m.pdb',
#  'data/pdb/KQ.m.pdb',
#  'data/pdb/KT.m.pdb',
#  'data/pdb/KV.m.pdb',
#  'data/pdb/KW.m.pdb',
#  'data/pdb/KX.m.pdb',
#  'data/pdb/KY.m.pdb',
#  'data/pdb/KZ.m.pdb',
#  'data/pdb/L9.m.pdb',
#  'data/pdb/LG.m.pdb',
#  'data/pdb/LH.m.pdb',
#  'data/pdb/LI.m.pdb',
#  'data/pdb/LL.m.pdb',
#  'data/pdb/LO.m.pdb',
#  'data/pdb/LP.m.pdb',
#  'data/pdb/LV.m.pdb',
#  'data/pdb/LX.m.pdb',
#  'data/pdb/LZ.m.pdb',
#  'data/pdb/M1.m.pdb',
#  'data/pdb/M2.m.pdb',
#  'data/pdb/M4.m.pdb',
#  'data/pdb/MI.m.pdb',
#  'data/pdb/MJ.m.pdb',
#  'data/pdb/MK.m.pdb',
#  'data/pdb/ML.m.pdb',
#  'data/pdb/MM.m.pdb',
#  'data/pdb/MO.m.pdb',
#  'data/pdb/MS.m.pdb',
#  'data/pdb/N0.m.pdb',
#  'data/pdb/N2.m.pdb',
#  'data/pdb/N6.m.pdb',
#  'data/pdb/N7.m.pdb',
#  'data/pdb/NF.m.pdb',
#  'data/pdb/NG.m.pdb',
#  'data/pdb/NH.m.pdb',
#  'data/pdb/NK.m.pdb',
#  'data/pdb/NM.m.pdb',
#  'data/pdb/NO.m.pdb',
#  'data/pdb/NT.m.pdb',
#  'data/pdb/NU.m.pdb',
#  'data/pdb/NV.m.pdb',
#  'data/pdb/NW.m.pdb',
#  'data/pdb/O1.m.pdb',
#  'data/pdb/O5.m.pdb',
#  'data/pdb/O7.m.pdb',
#  'data/pdb/O8.m.pdb',
#  'data/pdb/O9.m.pdb',
#  'data/pdb/OA.m.pdb',
#  'data/pdb/OD.m.pdb',
#  'data/pdb/ON.m.pdb',
#  'data/pdb/OS.m.pdb',
#  'data/pdb/OT.m.pdb',
#  'data/pdb/OX.m.pdb',
#  'data/pdb/P3.m.pdb',
#  'data/pdb/P4.m.pdb',
#  'data/pdb/P6.m.pdb',
#  'data/pdb/P7.m.pdb',
#  'data/pdb/PB.m.pdb',
#  'data/pdb/PC.m.pdb',
#  'data/pdb/PF.m.pdb',
#  'data/pdb/PG.m.pdb',
#  'data/pdb/PJ.m.pdb',
#  'data/pdb/PK.m.pdb',
#  'data/pdb/PL.m.pdb',
#  'data/pdb/PN.m.pdb',
#  'data/pdb/PO.m.pdb',
#  'data/pdb/PQ.m.pdb',
#  'data/pdb/PR.m.pdb',
#  'data/pdb/PS.m.pdb',
#  'data/pdb/PW.m.pdb',
#  'data/pdb/PX.m.pdb',
#  'data/pdb/PY.m.pdb',
#  'data/pdb/Q4.m.pdb',
#  'data/pdb/Q6.m.pdb',
#  'data/pdb/Q7.m.pdb',
#  'data/pdb/Q9.m.pdb',
#  'data/pdb/QA.m.pdb',
#  'data/pdb/QB.m.pdb',
#  'data/pdb/QC.m.pdb',
#  'data/pdb/QF.m.pdb',
#  'data/pdb/QG.m.pdb',
#  'data/pdb/QH.m.pdb',
#  'data/pdb/QI.m.pdb',
#  'data/pdb/QL.m.pdb',
#  'data/pdb/QR.m.pdb',
#  'data/pdb/QS.m.pdb',
#  'data/pdb/QT.m.pdb',
#  'data/pdb/QZ.m.pdb',
#  'data/pdb/R2.m.pdb',
#  'data/pdb/R3.m.pdb',
#  'data/pdb/R8.m.pdb',
#  'data/pdb/RA.m.pdb',
#  'data/pdb/RH.m.pdb',
#  'data/pdb/RV.m.pdb',
#  'data/pdb/RX.m.pdb',
#  'data/pdb/RY.m.pdb',
#  'data/pdb/RZ.m.pdb',
#  'data/pdb/S0.m.pdb',
#  'data/pdb/S1.m.pdb',
#  'data/pdb/S2.m.pdb',
#  'data/pdb/S3.m.pdb',
#  'data/pdb/S4.m.pdb',
#  'data/pdb/S5.m.pdb',
#  'data/pdb/S6.m.pdb',
#  'data/pdb/S7.m.pdb',
#  'data/pdb/S8.m.pdb',
#  'data/pdb/S9.m.pdb',
#  'data/pdb/SA.m.pdb',
#  'data/pdb/SG.m.pdb',
#  'data/pdb/SZ.m.pdb',
#  'data/pdb/T0.m.pdb',
#  'data/pdb/T1.m.pdb',
#  'data/pdb/T2.m.pdb',
#  'data/pdb/T3.m.pdb',
#  'data/pdb/T4.m.pdb',
#  'data/pdb/TB.m.pdb',
#  'data/pdb/TJ.m.pdb',
#  'data/pdb/TY.m.pdb',
#  'data/pdb/U4.m.pdb',
#  'data/pdb/U7.m.pdb',
#  'data/pdb/U8.m.pdb',
#  'data/pdb/UA.m.pdb',
#  'data/pdb/UB.m.pdb',
#  'data/pdb/UD.m.pdb',
#  'data/pdb/UF.m.pdb',
#  'data/pdb/UM.m.pdb',
#  'data/pdb/UN.m.pdb',
#  'data/pdb/UO.m.pdb',
#  'data/pdb/UQ.m.pdb',
#  'data/pdb/US.m.pdb',
#  'data/pdb/UW.m.pdb',
#  'data/pdb/UX.m.pdb',
#  'data/pdb/UY.m.pdb',
#  'data/pdb/V0.m.pdb',
#  'data/pdb/V5.m.pdb',
#  'data/pdb/VA.m.pdb',
#  'data/pdb/VI.m.pdb',
#  'data/pdb/VN.m.pdb',
#  'data/pdb/VP.m.pdb',
#  'data/pdb/VQ.m.pdb',
#  'data/pdb/VR.m.pdb',
#  'data/pdb/W0.m.pdb',
#  'data/pdb/W2.m.pdb',
#  'data/pdb/W3.m.pdb',
#  'data/pdb/W5.m.pdb',
#  'data/pdb/W7.m.pdb',
#  'data/pdb/WA.m.pdb',
#  'data/pdb/WB.m.pdb',
#  'data/pdb/WC.m.pdb',
#  'data/pdb/WD.m.pdb',
#  'data/pdb/WE.m.pdb',
#  'data/pdb/WH.m.pdb',
#  'data/pdb/WJ.m.pdb',
#  'data/pdb/WS.m.pdb',
#  'data/pdb/WY.m.pdb',
#  'data/pdb/WZ.m.pdb',
#  'data/pdb/X2.m.pdb',
#  'data/pdb/XF.m.pdb',
#  'data/pdb/XO.m.pdb',
#  'data/pdb/XT.m.pdb',
#  'data/pdb/XV.m.pdb',
#  'data/pdb/XZ.m.pdb',
#  'data/pdb/Y0.m.pdb',
#  'data/pdb/Y8.m.pdb',
#  'data/pdb/Y9.m.pdb',
#  'data/pdb/YA.m.pdb',
#  'data/pdb/YM.m.pdb',
#  'data/pdb/YN.m.pdb',
#  'data/pdb/YS.m.pdb',
#  'data/pdb/Z2.m.pdb',
#  'data/pdb/Z4.m.pdb',
#  'data/pdb/Z5.m.pdb',
#  'data/pdb/Z6.m.pdb',
#  'data/pdb/Z7.m.pdb',
#  'data/pdb/Z8.m.pdb',
#  'data/pdb/Z9.m.pdb',
#  'data/pdb/ZA.m.pdb',
#  'data/pdb/ZC.m.pdb',
#  'data/pdb/ZE.m.pdb',
#  'data/pdb/ZG.m.pdb',
#  'data/pdb/ZH.m.pdb',
#  'data/pdb/ZJ.m.pdb',
#  'data/pdb/ZM.m.pdb',
#  'data/pdb/ZP.m.pdb',
#  'data/pdb/ZR.m.pdb',
#  'data/pdb/ZX.m.pdb',
#  'data/pdb/ZY.m.pdb']

# %%
D.update_pdbs()
# Out:
# WARNING: The default download format has changed from PDB to PDBx/mmCif
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-a0d82fd1e398> in <module>
# ----> 1 D.update_pdbs()
#
# <ipython-input-21-e261a2c6a450> in update_pdbs(self)
#      44
#      45     def update_pdbs(self):
# ---> 46         updatepdbs(self.path_pdb)
#      47
#      48     # ======================================================================================================================
#
# ~\PycharmProjects\mt\gpcrdb_soup.py in updatepdbs(path)
#     168 def updatepdbs(path="/data/pdb"):
#     169     pl = PDBList(path)
# --> 170     return pl.update_pdb()
#
# ~\.conda\envs\mt\lib\site-packages\Bio\PDB\PDBList.py in update_pdb(self, file_format)
#     360         file_format = self._print_default_format_warning(file_format)
#     361
# --> 362         new, modified, obsolete = self.get_recent_changes()
#     363
#     364         for pdb_code in new + modified:
#
# ~\.conda\envs\mt\lib\site-packages\Bio\PDB\PDBList.py in get_recent_changes(self)
#     160
#     161         # Retrieve the lists
# --> 162         added = self.get_status_list(path + "added.pdb")
#     163         modified = self.get_status_list(path + "modified.pdb")
#     164         obsolete = self.get_status_list(path + "obsolete.pdb")
#
# ~\.conda\envs\mt\lib\site-packages\Bio\PDB\PDBList.py in get_status_list(url)
#     133         by this method is now very simply - one PDB name per line.
#     134         """
# --> 135         with contextlib.closing(urlopen(url)) as handle:
#     136             answer = []
#     137             for line in handle:
#
# ~\.conda\envs\mt\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# ~\.conda\envs\mt\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     507         # accept a URL or a Request object
#     508         if isinstance(fullurl, str):
# --> 509             req = Request(fullurl, data)
#     510         else:
#     511             req = fullurl
#
# ~\.conda\envs\mt\lib\urllib\request.py in __init__(self, url, data, headers, origin_req_host, unverifiable, method)
#     326                  origin_req_host=None, unverifiable=False,
#     327                  method=None):
# --> 328         self.full_url = url
#     329         self.headers = {}
#     330         self.unredirected_hdrs = {}
#
# ~\.conda\envs\mt\lib\urllib\request.py in full_url(self, url)
#     352         self._full_url = unwrap(url)
#     353         self._full_url, self.fragment = _splittag(self._full_url)
# --> 354         self._parse()
#     355
#     356     @full_url.deleter
#
# ~\.conda\envs\mt\lib\urllib\request.py in _parse(self)
#     381         self.type, rest = _splittype(self._full_url)
#     382         if self.type is None:
# --> 383             raise ValueError("unknown url type: %r" % self.full_url)
#     384         self.host, self.selector = _splithost(rest)
#     385         if self.host:
#
# ValueError: unknown url type: 'data/pdb/pub/pdb/data/status/latest/added.pdb'

# %%
class References():
    def __init__(self):
        # how to connect the Dataloaders
        pass

# %%
# ['PDB', 'Name', 'Uniprot', 'Sequence', 'Sections', 'Gaps','Structure', 'Ca','CaC','Psi','Phi','State', 'G-protein']

# %%
class DataLoader():
    def __init__(self):
        """
        Index:         Identifier for our data
        Type:          G-Protein/Receptor/?
        Function:      Agonist/Antagonist
        Seq:           Protein sequence from PDBs
        Uniprot_Seq:   Protein sequence from uniprot entry
        Sections:      Polypeptides with structure (Sequence)
        Gaps:          Indices of starts/ends in full protein sequence of the polypeptides
        Position_idx:  GPCRdb alignment position index (if possible)
        XYZ:           Structure Data contained in the PDB (saved as per-residue)
        XYZ_padded:    Including NaN values for AAs in Gaps
        Ca:            Position of the C-alphas
        CaC:           Direction of backbone
        Psi:           Psi angle
        Phi:           Phi angle
        State:         Active/Inactive (for Receptors)
        G-Protein:     Primary target I guess
        Selectivities: Selectivity Values
        References:    ???
        """
        columns = ['Index',
                   'Type',
                   'PDB', 'Name', 'Uniprot', 
                   'Seq', 'Uniprot_Seq',
                   'Sections', 'Gaps', 'Position_Idx'
                   'XYZ', 'XYZ_padded'
                   'Ca','CaC','Psi','Phi',
                   'State', 'G-protein',
                   'References']
        gproteins = ['gs', 'gi', 'gq']  # used in Selectivities to map the dict
        self.data = pd.DataFrame(columns = columns)
        
        # think about how to 
        
    # ======================================================================================================================
    
    def load_alignment(self):
        pass
    
    # ======================================================================================================================
    
    # PROCESSING
    
    # ======================================================================================================================
    
    def load_pkl(self, path: str):
        self.data = pd.read_pickle(path)
        
    def save_pkl(self, path: str):
        self.data.save_pickle(path)
        
    # ======================================================================================================================
    
    def separate_structure(self):
        # if structure is active: use another dict for g-protein/complex?
        pass
    
    # ======================================================================================================================
    
    def view(self, pdb=None, uniprot=None, idx=None, start=None, end=None, start_idx=None, end_idx=None):
        # implement a view of a protein
        # implement view of overlap of proteins
        pass

# %%
loader = DataLoader()

# %%
loader.data
# Out:
# Empty DataFrame
# Columns: [Index, Type, PDB, Name, Uniprot, Sequence, Sections, Gaps, Position_IdxStructure, Full_StructCa, CaC, Psi, Phi, State, G-protein, References]
# Index: []

# %%
del loader
