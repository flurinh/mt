# %%
import pandas as pd
import lxml

# %%
data = pd.read_html('data/couplings/families_coupling.xls')[0].drop('Unnamed: 0_level_0', axis=1)
# Out:
# c:\users\flurin hidber\anaconda3\envs\law\lib\site-packages\pandas\core\generic.py:4153: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   obj = obj._drop_axis(labels, axis, level=level, errors=errors)

# %%
data
# Out:
#       Source           Receptor                                          \
#        Group Biosensor       Cl           Receptor fam. Uniprot  IUPHAR
# 0     GPCRdb       Max        A     5-Hydroxytryptamine   5HT1A  5-HT1A
# 1    Bouvier     GEMTA        A     5-Hydroxytryptamine   5HT1A  5-HT1A
# 2      Inoue       TGF        A     5-Hydroxytryptamine   5HT1A  5-HT1A
# 3     GPCRdb       Max        A     5-Hydroxytryptamine   5HT1B  5-HT1B
# 4    Bouvier     GEMTA        A     5-Hydroxytryptamine   5HT1B  5-HT1B
# ..       ...       ...      ...                     ...     ...     ...
# 412  Bouvier     GEMTA        C  Metabotropic glutamate    GRM5   mGlu5
# 413   GPCRdb       Max        C  Metabotropic glutamate    GRM6   mGlu6
# 414  Bouvier     GEMTA        C  Metabotropic glutamate    GRM6   mGlu6
# 415   GPCRdb       Max        C  Metabotropic glutamate    GRM8   mGlu8
# 416  Bouvier     GEMTA        C  Metabotropic glutamate    GRM8   mGlu8
#
#     Guide to Pharmacology                    ... Log(Emax/EC50)        pEC50  \
#                        Gs Gi/o Gq/11 G12/13  ...          Gq/11 G12/13    Gs
# 0                       -   1'     -      -  ...            6.7      -     -
# 1                       -   1'     -      -  ...            6.7    0.0   0.0
# 2                       -   1'     -      -  ...            6.7    5.3   5.9
# 3                       -   1'     -      -  ...            6.7      -     -
# 4                       -   1'     -      -  ...            6.2    0.0   0.0
# ..                    ...  ...   ...    ...  ...            ...    ...   ...
# 412                    2'   2'    1'      -  ...            5.8    0.0   0.0
# 413                     -   1'     -      -  ...              -      -     -
# 414                     -   1'     -      -  ...            0.0    0.0   0.0
# 415                     -   1'     -      -  ...              -      -     -
# 416                     -   1'     -      -  ...            0.0    0.0   0.0
#
#                       Emax
#     Gi/o Gq/11 G12/13   Gs Gi/o Gq/11 G12/13
# 0    8.6   7.1      -    -   68    75      -
# 1    8.6   6.8    0.0    0   68    75      0
# 2    7.0   7.1    5.9   20   48    41     26
# 3    9.6   7.4      -    -   33    22      -
# 4    9.6   7.2    0.0    0   33    11      0
# ..   ...   ...    ...  ...  ...   ...    ...
# 412  5.8   6.3    0.0    0   52    45      0
# 413  5.3     -      -    -   36     -      -
# 414  5.3   0.0    0.0    0   36     0      0
# 415  6.1     -      -    -   45     -      -
# 416  6.1   0.0    0.0    0   45     0      0
#
# [417 rows x 22 columns]

# %%
data.columns
# Out:
# MultiIndex([(               'Source',         'Group'),
#             (               'Source',     'Biosensor'),
#             (             'Receptor',            'Cl'),
#             (             'Receptor', 'Receptor fam.'),
#             (             'Receptor',       'Uniprot'),
#             (             'Receptor',        'IUPHAR'),
#             ('Guide to Pharmacology',            'Gs'),
#             ('Guide to Pharmacology',          'Gi/o'),
#             ('Guide to Pharmacology',         'Gq/11'),
#             ('Guide to Pharmacology',        'G12/13'),
#             (       'Log(Emax/EC50)',            'Gs'),
#             (       'Log(Emax/EC50)',          'Gi/o'),
#             (       'Log(Emax/EC50)',         'Gq/11'),
#             (       'Log(Emax/EC50)',        'G12/13'),
#             (                'pEC50',            'Gs'),
#             (                'pEC50',          'Gi/o'),
#             (                'pEC50',         'Gq/11'),
#             (                'pEC50',        'G12/13'),
#             (                 'Emax',            'Gs'),
#             (                 'Emax',          'Gi/o'),
#             (                 'Emax',         'Gq/11'),
#             (                 'Emax',        'G12/13')],
#            )

# %%
class AffinityProcessor:
    def __init__(self,
                 path='data/couplings/',
                 setting='subtypes'):
        self.source = path + setting + '_coupling.xls'
        self.setting = setting
        self.groups = ['GPCRdb', 'Inoue', 'Bouvier']
        self.label_types = ['Guide to Pharmacology', 'Log(Emax/EC50)', 'pEC50', 'Emax']
        print("Initialized Affinity Processor...")
        print("Please set a group --------------  {}.".format(self.groups))
        print("please set label type -----------  {}.".format(self.label_types))
    
    def read_data(self):
        self.data = pd.read_html(self.source)[0].drop('Unnamed: 0_level_0', axis=1, level=0)
    
    def set_group(self, group='GPCRdb'):
        assert group in self.groups, print("'{}' is not a valid group name, valid are {}.".format(group, self.groups))
        print("\nSelected data of group {}.\n".format(group))
        if self.setting == 'subtypes':
            self.data = self.data[self.data['Source', 'Group', 'Unnamed: 1_level_2']=='GPCRdb']
            
    def set_label_type(self, label_type='Guide to Pharmacology'):
        assert label_type in self.label_types, print("'{}' is not a valid label type, valid are {}."\
                                                     .format(label_type, self.label_types))
        print("\nSelected label type '{}'.\n".format(label_type))
        to_drop = [x for x in self.label_types if x != label_type]
        if self.setting == 'subtypes':
            self.data = self.data.drop(to_drop, axis=1)
        
    def make_label_dict(self):
        return label_dict

# %%
A = AffinityProcessor()
A.set_label_type()
A.set_group()
# Out:
# Initialized Affinity Processor...
# Please set a group --------------  ['GPCRdb', 'Inoue', 'Bouvier'].
# please set label type -----------  ['Guide to Pharmacology', 'Log(Emax/EC50)', 'pEC50', 'Emax'].
#
# Selected label type 'Guide to Pharmacology'.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\flurin hidber\anaconda3\envs\law\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Log(Emax/EC50)'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-84-7dfe1698065e> in <module>
#       1 A = AffinityProcessor()
# ----> 2 A.set_label_type()
#       3 A.set_group()
#
# <ipython-input-83-99c02423252e> in set_label_type(self, label_type)
#      24         to_drop = [x for x in self.label_types if x != label_type]
#      25         if self.setting == 'subtypes':
# ---> 26             self.data = self.data.drop(to_drop, axis=1)
#      27
#      28     def make_label_dict(self):
#
# c:\users\flurin hidber\anaconda3\envs\law\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4313             level=level,
#    4314             inplace=inplace,
# -> 4315             errors=errors,
#    4316         )
#    4317
#
# c:\users\flurin hidber\anaconda3\envs\law\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# c:\users\flurin hidber\anaconda3\envs\law\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    4186                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4187             else:
# -> 4188                 new_axis = axis.drop(labels, errors=errors)
#    4189             result = self.reindex(**{axis_name: new_axis})
#    4190
#
# c:\users\flurin hidber\anaconda3\envs\law\lib\site-packages\pandas\core\indexes\multi.py in drop(self, codes, level, errors)
#    2162         for level_codes in codes:
#    2163             try:
# -> 2164                 loc = self.get_loc(level_codes)
#    2165                 # get_loc returns either an integer, a slice, or a boolean
#    2166                 # mask
#
# c:\users\flurin hidber\anaconda3\envs\law\lib\site-packages\pandas\core\indexes\multi.py in get_loc(self, key, method)
#    2874
#    2875         if not isinstance(key, tuple):
# -> 2876             loc = self._get_level_indexer(key, level=0)
#    2877             return _maybe_to_slice(loc)
#    2878
#
# c:\users\flurin hidber\anaconda3\envs\law\lib\site-packages\pandas\core\indexes\multi.py in _get_level_indexer(self, key, level, indexer)
#    3156         else:
#    3157
# -> 3158             idx = self._get_loc_single_level_index(level_index, key)
#    3159
#    3160             if level > 0 or self.lexsort_depth == 0:
#
# c:\users\flurin hidber\anaconda3\envs\law\lib\site-packages\pandas\core\indexes\multi.py in _get_loc_single_level_index(self, level_index, key)
#    2807             return -1
#    2808         else:
# -> 2809             return level_index.get_loc(key)
#    2810
#    2811     def get_loc(self, key, method=None):
#
# c:\users\flurin hidber\anaconda3\envs\law\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'Log(Emax/EC50)'

# %%
A.data.columns
# Out:
# MultiIndex([(               'Source',         'Group',  'Unnamed: 1_level_2'),
#             (               'Source',     'Biosensor',  'Unnamed: 2_level_2'),
#             (             'Receptor',            'Cl',  'Unnamed: 3_level_2'),
#             (             'Receptor', 'Receptor fam.',  'Unnamed: 4_level_2'),
#             (             'Receptor',       'Uniprot',  'Unnamed: 5_level_2'),
#             (             'Receptor',        'IUPHAR',  'Unnamed: 6_level_2'),
#             ('Guide to Pharmacology',            'Gs',  'Unnamed: 7_level_2'),
#             ('Guide to Pharmacology',          'Gi/o',  'Unnamed: 8_level_2'),
#             ('Guide to Pharmacology',         'Gq/11',  'Unnamed: 9_level_2'),
#             ('Guide to Pharmacology',        'G12/13', 'Unnamed: 10_level_2'),
#             (       'log(Emax/EC50)',            'Gs',               'GNAS2'),
#             (       'log(Emax/EC50)',            'Gs',                'GNAL'),
#             (       'log(Emax/EC50)',          'Gi/o',               'GNAI1'),
#             (       'log(Emax/EC50)',          'Gi/o',               'GNAI2'),
#             (       'log(Emax/EC50)',          'Gi/o',               'GNAI3'),
#             (       'log(Emax/EC50)',          'Gi/o',                'GNAZ'),
#             (       'log(Emax/EC50)',          'Gi/o',                'GNAO'),
#             (       'log(Emax/EC50)',         'Gq/11',                'GNAQ'),
#             (       'log(Emax/EC50)',         'Gq/11',               'GNA11'),
#             (       'log(Emax/EC50)',         'Gq/11',               'GNA14'),
#             (       'log(Emax/EC50)',         'Gq/11',               'GNA15'),
#             (       'log(Emax/EC50)',        'G12/13',               'GNA12'),
#             (       'log(Emax/EC50)',        'G12/13',               'GNA13'),
#             (                'pEC50',            'Gs',               'GNAS2'),
#             (                'pEC50',            'Gs',                'GNAL'),
#             (                'pEC50',          'Gi/o',               'GNAI1'),
#             (                'pEC50',          'Gi/o',               'GNAI2'),
#             (                'pEC50',          'Gi/o',               'GNAI3'),
#             (                'pEC50',          'Gi/o',                'GNAZ'),
#             (                'pEC50',          'Gi/o',                'GNAO'),
#             (                'pEC50',         'Gq/11',                'GNAQ'),
#             (                'pEC50',         'Gq/11',               'GNA11'),
#             (                'pEC50',         'Gq/11',               'GNA14'),
#             (                'pEC50',         'Gq/11',               'GNA15'),
#             (                'pEC50',        'G12/13',               'GNA12'),
#             (                'pEC50',        'G12/13',               'GNA13'),
#             (                 'Emax',            'Gs',               'GNAS2'),
#             (                 'Emax',            'Gs',                'GNAL'),
#             (                 'Emax',          'Gi/o',               'GNAI1'),
#             (                 'Emax',          'Gi/o',               'GNAI2'),
#             (                 'Emax',          'Gi/o',               'GNAI3'),
#             (                 'Emax',          'Gi/o',                'GNAZ'),
#             (                 'Emax',          'Gi/o',                'GNAO'),
#             (                 'Emax',         'Gq/11',                'GNAQ'),
#             (                 'Emax',         'Gq/11',               'GNA11'),
#             (                 'Emax',         'Gq/11',               'GNA14'),
#             (                 'Emax',         'Gq/11',               'GNA15'),
#             (                 'Emax',        'G12/13',               'GNA12'),
#             (                 'Emax',        'G12/13',               'GNA13')],
#            )

# %%
A.data.get_level_values(0)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-86-e7469256abd0> in <module>
# ----> 1 A.data.get_level_values(0)
#
# c:\users\flurin hidber\anaconda3\envs\law\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'get_level_values'

# %%
data1 = pd.read_html('data/couplings/subtypes_coupling.xls')[0].drop('Unnamed: 0_level_0', axis=1)
# Out:
# c:\users\flurin hidber\anaconda3\envs\law\lib\site-packages\pandas\core\generic.py:4153: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   obj = obj._drop_axis(labels, axis, level=level, errors=errors)

# %%
data1[data1['Source', 'Group', 'Unnamed: 1_level_2']=='GPCRdb']
# Out:
#                 Source                              Receptor  \
#                  Group          Biosensor                 Cl
#     Unnamed: 1_level_2 Unnamed: 2_level_2 Unnamed: 3_level_2
# 0               GPCRdb               Mean                  A
# 3               GPCRdb               Mean                  A
# 6               GPCRdb               Mean                  A
# 9               GPCRdb               Mean                  A
# 11              GPCRdb               Mean                  A
# ..                 ...                ...                ...
# 407             GPCRdb               Mean                  C
# 409             GPCRdb               Mean                  C
# 411             GPCRdb               Mean                  C
# 413             GPCRdb               Mean                  C
# 415             GPCRdb               Mean                  C
#
#                                                                    \
#               Receptor fam.            Uniprot             IUPHAR
#          Unnamed: 4_level_2 Unnamed: 5_level_2 Unnamed: 6_level_2
# 0       5-Hydroxytryptamine              5HT1A             5-HT1A
# 3       5-Hydroxytryptamine              5HT1B             5-HT1B
# 6       5-Hydroxytryptamine              5HT1D             5-HT1D
# 9       5-Hydroxytryptamine              5HT1E             5-ht1E
# 11      5-Hydroxytryptamine              5HT1F             5-HT1F
# ..                      ...                ...                ...
# 407  Metabotropic glutamate               GRM2              mGlu2
# 409  Metabotropic glutamate               GRM4              mGlu4
# 411  Metabotropic glutamate               GRM5              mGlu5
# 413  Metabotropic glutamate               GRM6              mGlu6
# 415  Metabotropic glutamate               GRM8              mGlu8
#
#     Guide to Pharmacology                                        \
#                        Gs               Gi/o              Gq/11
#        Unnamed: 7_level_2 Unnamed: 8_level_2 Unnamed: 9_level_2
# 0                       -                 1'                  -
# 3                       -                 1'                  -
# 6                       -                 1'                  -
# 9                       -                 1'                  -
# 11                      -                 1'                  -
# ..                    ...                ...                ...
# 407                     -                 1'                  -
# 409                     -                 1'                  -
# 411                    2'                 2'                 1'
# 413                     -                 1'                  -
# 415                     -                 1'                  -
#
#                          ...  Emax                                          \
#                  G12/13  ...  Gi/o                 Gq/11
#     Unnamed: 10_level_2  ... GNAI2 GNAI3 GNAZ GNAO  GNAQ GNA11 GNA14 GNA15
# 0                     -  ...    50    39   44   52     -     -    27    52
# 3                     -  ...    23    26   30   20     -     -     -     -
# 6                     -  ...    20    17   33   26     -     -     -     -
# 9                     -  ...    16    25   15   13     -     -     -     -
# 11                    -  ...    16    28   1'    2     -     -     -     -
# ..                  ...  ...   ...   ...  ...  ...   ...   ...   ...   ...
# 407                   -  ...    21    1'    9   21     -     -     -     -
# 409                   -  ...    1'    1'   1'   14     -     -     -     -
# 411                   -  ...    33    2'   28   40    19    29    25    45
# 413                   -  ...    31    1'   25   24     -     -     -     -
# 415                   -  ...    27    1'   32   15     -     -     -     -
#
#
#     G12/13
#      GNA12 GNA13
# 0        -     -
# 3        -     -
# 6        -     -
# 9        -     -
# 11       -     -
# ..     ...   ...
# 407      -     -
# 409      -     -
# 411      -     -
# 413      -     -
# 415      -     -
#
# [173 rows x 49 columns]

# %%
from bs4 import BeautifulSoup

"""
with open(path) as f:
    text = f.read()
BeautifulSoup(text, 'lxml')"""
# Out:
# "\nwith open(path) as f:\n    text = f.read()\nBeautifulSoup(text, 'lxml')"

# %%
def get_families(path = 'data/families.txt'):
    with open(path) as f:
        cols = ['f1', 'v1', 'f2', 'v2', 'f3', 'v3', 'f4', 'v4']
        family_df = pd.DataFrame(columns=cols)
        v0_ = 0
        v1_ = 0
        v2_ = 0
        v3_ = 0
        for row in f.readlines():
            if not '    ' in row:
                v0 = row.split('|')[0][:-1]
                v0_ += 1
                v1_ = 0
                v2_ = 0
                v3_ = 0
            elif not '        ' in row:
                v1 = row.replace("\n", "")[4:]
                v1_ += 1
                v2_ = 0
                v3_ = 0
            elif not '            ' in row:
                v2 = row.replace("        ", "").replace("\n", "")
                v2_ += 1
                v3_ = 0
            else:
                try:
                    v3 = row.split(',')[8]
                    v3_ += 1
                except:
                    v3 = row.split(',')
                    v3_ += 1
                dict_ = dict(zip(cols, [v0, v0_, v1, v1_, v2, v2_, v3, v3_]))
                family_df=family_df.append(dict_, ignore_index=True)
    return family_df

# %%
family_df.to_pickle('data/families.pkl')

# %%
family_df
# Out:
#                       f1 v1                   f2 v2  \
# 0    Class A (Rhodopsin)  1  Aminergic receptors  1
# 1    Class A (Rhodopsin)  1  Aminergic receptors  1
# 2    Class A (Rhodopsin)  1  Aminergic receptors  1
# 3    Class A (Rhodopsin)  1  Aminergic receptors  1
# 4    Class A (Rhodopsin)  1  Aminergic receptors  1
# ..                   ... ..                  ... ..
# 418          Other GPCRs  8     Orphan receptors  1
# 419          Other GPCRs  8     Orphan receptors  1
# 420          Other GPCRs  8     Orphan receptors  1
# 421          Other GPCRs  8     Orphan receptors  1
# 422          Other GPCRs  8     Orphan receptors  1
#
#                                 f3 v3  \
# 0    5-Hydroxytryptamine receptors  1
# 1    5-Hydroxytryptamine receptors  1
# 2    5-Hydroxytryptamine receptors  1
# 3    5-Hydroxytryptamine receptors  1
# 4    5-Hydroxytryptamine receptors  1
# ..                             ... ..
# 418             Other GPCR orphans  1
# 419             Other GPCR orphans  1
# 420             Other GPCR orphans  1
# 421             Other GPCR orphans  1
# 422             Other GPCR orphans  1
#
#                                                     f4 v4
# 0    "ADRBRL1|5-HT1A|ADRB2RL1|serotonin receptor 1A...  1
# 1    "5-HT1B|5-HT1DB|HTR1D2|5-HT1B serotonin recept...  2
# 2    "5-HT<sub>1D&alpha;</sub>|HTRL|5-HT1D|HT1DA|se...  3
# 3    "5-HT<sub>1E</sub><sub>&alpha;</sub>|5-HT1E|5-...  4
# 4    "5-HT<sub>1E&beta;</sub>|5-HT<sub>6</sub>|5-HT...  5
# ..                                                 ... ..
# 418  "GPR137A|TM7SF1L1|TM7SF1|Transmembrane 7 super...  2
# 419  "GPR136|GPR164|Olfactory receptor 51E1|OR52A3P...  3
# 420  "GPR175|TMEM227|TPRA40|G protein-coupled recep...  4
# 421  "MOA1|ocular albinism 1 (Nettleship-Falls)|NYS...  5
# 422                                                 ""  6
#
# [423 rows x 8 columns]
