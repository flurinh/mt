# %%
from processing.processor import *
from analysis.stdanalysis import *
from analysis.analysis import *
import numpy as np
from scipy.spatial.distance import cdist, pdist
import seaborn as sns

# %% [markdown]
# # Analysis complexes

# %%
p = CifProcessor()
p.read_pkl_metainfo()
p.read_pkl(mode='rg', folder='data/processed/')
# Out:
#   3%|███▎                                                                                                              | 16/557 [00:00<00:03, 154.59it/s]
# Reading files with generic numbers on receptors and gproteins.
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 557/557 [00:04<00:00, 122.79it/s]

# %%
f_gio = p.make_filter(State='Active', Cl='Rhodopsin', Family='Gi/o', gprotein=True)
fuf = f_gio[f_gio['PDB']=='6FUF']
f_gio = f_gio[f_gio['Method']!='X-ray']
# Combine with 6FUF
f_gio = f_gio.append(fuf).reset_index(drop=True)
print("Number of samples in complex with G_i/o:", len(f_gio))
# Out:
# Number of samples in complex with G_i/o: 35

# %%
f_gs = p.make_filter(State='Active', Cl='Rhodopsin', Family='Gs', gprotein=True)
print("Number of samples in complex with G_s:", len(f_gs))
# Out:
# Number of samples in complex with G_s: 33

# %%
f_q11 = p.make_filter(State='Active', Cl='Rhodopsin', Family='Gq/11', gprotein=True)
print("Number of samples in complex with G_qq/11:", len(f_q11))
# Out:
# Number of samples in complex with G_qq/11: 4

# %%
f_tot = pd.concat([f_gio, f_gs, f_q11]).reset_index(drop=True)

# %%
p.apply_filter(f_tot)

# %%
filtered_indices_q11 = [x for x in p.get_dfl_indices(list(f_q11['PDB'])) if x != None]
filtered_indices_gs = [x for x in p.get_dfl_indices(list(f_gs['PDB'])) if x != None]
filtered_indices_gio = [x for x in p.get_dfl_indices(list(f_gio['PDB'])) if x != None]

# %%
l = [filtered_indices_gio, filtered_indices_gs, filtered_indices_q11]

# %% [markdown]
# ## Distances

# %%
A = StdAnalysisComplexes(P=p)
len(A.P.dfl)
# Out:
# 72

# %%
tm_loc = 3.5
tm_str = str(round(tm_loc, 1))
print(tm_str)
# Out:
# 3.5

# %% [markdown]
# ### gs

# %%
A.run_dist_analysis(l=[filtered_indices_gs], query_tag='gs', poi=('G.H5.19', tm_loc), eps=0.05)

# %%
dfs_gs = A.make_overview_df()

# %%
make_overview_plots(dfs_gs[1].loc['G.H5.13':, :], 
                    title='Mean TM '+tm_str, cl='A (Rhodopsin)', gprot='Gprotein Family Gs', 
                    figsize=(8, 5), path='plots/mt/', show=False, save=True,
                    dpi=600)

# %%
make_overview_plots(dfs_gs[2].loc['G.H5.13':, :], 
                    title='Standard deviation TM '+tm_str, cl='Receptor class A (Rhodopsin)', gprot='Gprotein Family Gs', 
                    figsize=(8, 5), path='plots/mt/', show=False, save=True,
                    dpi=600, dmax=3, cmap='plasma')

# %%
len(A.dist_df_dict)
# Out:
# 22

# %% [markdown]
# ### gio

# %%
del A
A = StdAnalysisComplexes(P=p)
A.run_dist_analysis(l=[filtered_indices_gio], query_tag='gio', poi=('G.H5.19', tm_loc), eps=0.05)

# %%
dfs_gio = A.make_overview_df()

# %%
make_overview_plots(dfs_gio[1].loc['G.H5.13':, :], 
                    title='Mean TM '+tm_str, set_title=False, cl='A (Rhodopsin)', gprot='Gprotein Family Gio', 
                    figsize=(8, 5), path='plots/mt/', show=False, save=True,
                    dpi=600)

# %%
make_overview_plots(dfs_gio[2].loc['G.H5.13':, :], 
                    title='Standard deviation TM '+tm_str, cl='Receptor class A (Rhodopsin)', gprot='Gprotein Family Gio', 
                    figsize=(8, 5), path='plots/mt/', show=False, save=True,
                    dpi=600, dmax=3, cmap='plasma')

# %%
len(A.dist_df_dict)
# Out:
# 26

# %% [markdown]
# ### gq11

# %%
del A
A = StdAnalysisComplexes(P=p)
A.run_dist_analysis(l=[filtered_indices_q11], query_tag='gq11', poi=('G.H5.19', tm_loc), eps=0.05)

# %%
dfs_gq11 = A.make_overview_df()

# %%
make_overview_plots(dfs_gq11[1].loc['G.H5.13':, :], 
                    title='Mean TM'+tm_str, cl='A (Rhodopsin)', gprot='Gprotein Family Gq and G11', 
                    figsize=(8, 5), path='plots/mt/', show=False, save=True,
                    dpi=600)

# %%
make_overview_plots(dfs_gq11[2].loc['G.H5.13':, :8.52], 
                    title='Standard deviation TM '+tm_str, cl='Receptor class A (Rhodopsin)', gprot='Gprotein Family Gq and G11', 
                    figsize=(8, 5), path='plots/mt/', show=False, save=True,
                    dpi=600, dmax=3, cmap='plasma')

# %%
len(A.dist_df_dict)
# Out:
# 3

# %% [markdown]
# ## Helix angles

# %%
def get_mask(df):
    for i in range(len(df)):
        col = list(df.columns)[i]
        df.loc[col, col] = 0.
    mask = np.zeros(df.values.shape,dtype='bool')
    mask[np.triu_indices(len(A.helical_angles_mean))] = True
    return mask

# %% [markdown]
# ### gio

# %%
p = CifProcessor()
p.read_pkl_metainfo()
p.read_pkl(mode='rg', folder='data/processed/')
f_gio = p.make_filter(State='Active', Cl='Rhodopsin', Family='Gi/o', gprotein=True)
fuf = f_gio[f_gio['PDB']=='6FUF']
f_gio = f_gio[f_gio['Method']!='X-ray']
# Combine with 6FUF
f_gio = f_gio.append(fuf).reset_index(drop=True)
print("Number of samples in complex with G_i/o:", len(f_gio))
p.apply_filter(f_gio)
del A
A = StdAnalysisComplexes(P=p)
A.run_helical_analysis()
gio_ham = A.helical_angles_mean
gio_has = A.helical_angles_std
mask = get_mask(A.helical_angles_mean)
# Out:
#   3%|███                                                                                                               | 15/557 [00:00<00:03, 147.02it/s]
# Reading files with generic numbers on receptors and gproteins.
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 557/557 [00:04<00:00, 130.26it/s]
# Number of samples in complex with G_i/o: 35

# %%
with sns.axes_style("white"):
    ax = sns.heatmap(A.helical_angles_std.astype(float).loc['TM2':, :'TM7'], mask=mask[1:, :-1], vmax=15, square=False)

# %%
fig = ax.get_figure()
fig.savefig("plots/mt/gio_helices.png")

# %%
A.helical_angles_mean
# Out:
#            TM1        TM2        TM3        TM4        TM5        TM6  \
# TM1        0.0  38.137677  45.117318  40.939798  69.249379  58.401845
# TM2  38.137677        0.0  16.467058  36.769586  45.349765  54.800146
# TM3  45.117318  16.467058        0.0  25.611045  29.954459   40.47176
# TM4  40.939798  36.769586  25.611045        0.0  31.928548  20.553265
# TM5  69.249379  45.349765  29.954459  31.928548        0.0  28.450892
# TM6  58.401845  54.800146   40.47176  20.553265  28.450892        0.0
# TM7  34.530298  36.030056  27.622599   7.385344  38.151169  25.321667
# H8   81.417704  56.107502  63.899548  81.739333   74.32537  74.789796
#
#            TM7         H8
# TM1  34.530298  81.417704
# TM2  36.030056  56.107502
# TM3  27.622599  63.899548
# TM4   7.385344  81.739333
# TM5  38.151169   74.32537
# TM6  25.321667  74.789796
# TM7        0.0  81.796247
# H8   81.796247        0.0

# %% [markdown]
# ### gs

# %%
p = CifProcessor()
p.read_pkl_metainfo()
p.read_pkl(mode='rg', folder='data/processed/')
f_gs = p.make_filter(State='Active', Cl='Rhodopsin', Family='Gs', gprotein=True)
print("Number of samples in complex with G_s:", len(f_gs))
p.apply_filter(f_gs)
del A
A = StdAnalysisComplexes(P=p)
A.run_helical_analysis()
gs_ham = A.helical_angles_mean
gs_has = A.helical_angles_std
mask = get_mask(A.helical_angles_mean.loc['TM2':, :'H8'])
# Out:
#   2%|██▋                                                                                                               | 13/557 [00:00<00:04, 129.97it/s]
# Reading files with generic numbers on receptors and gproteins.
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 557/557 [00:04<00:00, 128.58it/s]
# Number of samples in complex with G_s: 33

# %%
with sns.axes_style("white"):
    ax = sns.heatmap(A.helical_angles_mean.astype(float).loc['TM2':, :'TM7'], mask=mask[1:, :-1], vmax=90, square=False)

# %%
fig = ax.get_figure()
fig.savefig("plots/mt/gs_helices.png")

# %%
A.helical_angles_mean
# Out:
#            TM1        TM2        TM3        TM4        TM5        TM6  \
# TM1        NaN  38.921913  46.201423  39.858065  68.056645  58.293821
# TM2  38.921913        NaN   17.60071  36.884335  45.419106  56.959454
# TM3  46.201423   17.60071        NaN   25.24665  29.272634  41.807263
# TM4  39.858065  36.884335   25.24665        NaN  31.449158  21.967816
# TM5  68.056645  45.419106  29.272634  31.449158        NaN  28.675837
# TM6  58.293821  56.959454  41.807263  21.967816  28.675837        NaN
# TM7  32.446604  37.025285  29.222101   8.456283  39.121398  26.951167
# H8   79.677008  54.831316  60.407103  79.641884  66.419015  80.834023
#
#            TM7         H8
# TM1  32.446604  79.677008
# TM2  37.025285  54.831316
# TM3  29.222101  60.407103
# TM4   8.456283  79.641884
# TM5  39.121398  66.419015
# TM6  26.951167  80.834023
# TM7        NaN  82.333567
# H8   82.333567        NaN

# %% [markdown]
# ### gq11

# %%
p = CifProcessor()
p.read_pkl_metainfo()
p.read_pkl(mode='rg', folder='data/processed/')
f_q11 = p.make_filter(State='Active', Cl='Rhodopsin', Family='Gq/11', gprotein=True)
print("Number of samples in complex with G_s:", len(f_q11))
p.apply_filter(f_q11)
del A
A = StdAnalysisComplexes(P=p)
A.run_helical_analysis()
gq11_ham = A.helical_angles_mean
gq11_has = A.helical_angles_std
mask = get_mask(A.helical_angles_mean.loc['TM2':, :'H8'])
# Out:
#   3%|███▎                                                                                                              | 16/557 [00:00<00:03, 142.95it/s]
# Reading files with generic numbers on receptors and gproteins.
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 557/557 [00:04<00:00, 128.17it/s]
# Number of samples in complex with G_s: 4

# %%
with sns.axes_style("white"):
    ax = sns.heatmap(A.helical_angles_mean.astype(float).loc['TM2':, :'TM7'], mask=mask[1:, :-1], vmax=90, square=False)

# %%
fig = ax.get_figure()
fig.savefig("plots/mt/gq11_helices.png")

# %%
A.helical_angles_mean
# Out:
#            TM1        TM2        TM3        TM4        TM5        TM6  \
# TM1        NaN  37.688323  48.448884  42.243169   71.53043  58.150984
# TM2  37.688323        NaN  19.026833  37.531464  48.560875  55.054036
# TM3  48.448884  19.026833        NaN  26.650623   29.64082  40.523564
# TM4  42.243169  37.531464  26.650623        NaN  31.908303  18.700668
# TM5   71.53043  48.560875   29.64082  31.908303        NaN  28.567734
# TM6  58.150984  55.054036  40.523564  18.700668  28.567734        NaN
# TM7  34.153623  34.844622  28.679745   8.584551  39.519653  25.501462
# H8   77.936482  48.189833  50.097683  76.038036  62.356058  80.410023
#
#            TM7         H8
# TM1  34.153623  77.936482
# TM2  34.844622  48.189833
# TM3  28.679745  50.097683
# TM4   8.584551  76.038036
# TM5  39.519653  62.356058
# TM6  25.501462  80.410023
# TM7        NaN  77.390418
# H8   77.390418        NaN

# %% [markdown]
# ## Angle diffs

# %% [markdown]
# ### gs vs gio

# %%
gio_ham
# Out:
#            TM1        TM2        TM3        TM4        TM5        TM6  \
# TM1        0.0  38.137677  45.117318  40.939798  69.249379  58.401845
# TM2  38.137677        0.0  16.467058  36.769586  45.349765  54.800146
# TM3  45.117318  16.467058        0.0  25.611045  29.954459   40.47176
# TM4  40.939798  36.769586  25.611045        0.0  31.928548  20.553265
# TM5  69.249379  45.349765  29.954459  31.928548        0.0  28.450892
# TM6  58.401845  54.800146   40.47176  20.553265  28.450892        0.0
# TM7  34.530298  36.030056  27.622599   7.385344  38.151169  25.321667
# H8   81.417704  56.107502  63.899548  81.739333   74.32537  74.789796
#
#            TM7         H8
# TM1  34.530298  81.417704
# TM2  36.030056  56.107502
# TM3  27.622599  63.899548
# TM4   7.385344  81.739333
# TM5  38.151169   74.32537
# TM6  25.321667  74.789796
# TM7        0.0  81.796247
# H8   81.796247        0.0

# %%
gs_ham
# Out:
#            TM1        TM2        TM3        TM4        TM5        TM6  \
# TM1        NaN  38.921913  46.201423  39.858065  68.056645  58.293821
# TM2  38.921913        NaN   17.60071  36.884335  45.419106  56.959454
# TM3  46.201423   17.60071        NaN   25.24665  29.272634  41.807263
# TM4  39.858065  36.884335   25.24665        NaN  31.449158  21.967816
# TM5  68.056645  45.419106  29.272634  31.449158        NaN  28.675837
# TM6  58.293821  56.959454  41.807263  21.967816  28.675837        NaN
# TM7  32.446604  37.025285  29.222101   8.456283  39.121398  26.951167
# H8   79.677008  54.831316  60.407103  79.641884  66.419015  80.834023
#
#            TM7         H8
# TM1  32.446604  79.677008
# TM2  37.025285  54.831316
# TM3  29.222101  60.407103
# TM4   8.456283  79.641884
# TM5  39.121398  66.419015
# TM6  26.951167  80.834023
# TM7        NaN  82.333567
# H8   82.333567        NaN

# %%
ham_diff = np.abs(gio_ham - gs_ham)

# %%
has_diff = np.abs(gio_has - gs_has)

# %%
ham_mask = get_mask(ham_diff.loc['TM2':, :'H8'])

# %%
has_mask = get_mask(has_diff.loc['TM2':, :'H8'])

# %%
with sns.axes_style("white"):
    ax = sns.heatmap(ham_diff.astype(float).loc['TM2':, :'TM7'], mask=ham_mask[1:, :-1], vmax=10, square=False)

# %%
fig = ax.get_figure()
fig.savefig("plots/mt/ham_diff_gs_gio.png")

# %%
with sns.axes_style("white"):
    ax = sns.heatmap(has_diff.astype(float).loc['TM2':, :'TM7'], mask=has_mask[1:, :-1], vmax=6, square=False)

# %%
fig = ax.get_figure()
fig.savefig("plots/mt/has_diff_gs_gio.png")

# %%
A.helices
# Out:
#                                                     TM1  \
# 6OIJ  [0.4446112191463715, -0.838394123506787, -0.31...
# 6WHA  [-0.39687289659885133, -0.9133373071796915, -0...
# 7DFL  [0.47562373778023737, 0.01519263401304638, -0....
# 7MBY  [-0.22575044634720257, 0.01152216391865557, -0...
#
#                                                     TM2  \
# 6OIJ  [-0.4834688165241038, 0.36707203549194845, 0.7...
# 6WHA  [-0.20679047196621206, 0.9391040156684831, 0.2...
# 7DFL  [-0.8268332960467756, -0.33341081329720434, 0....
# 7MBY  [0.3158758234833395, 0.5823533666282076, 0.749...
#
#                                                     TM3  \
# 6OIJ  [0.12499354231819634, -0.3782787755506486, -0....
# 6WHA  [0.2515388052702665, -0.786402985921445, -0.56...
# 7DFL  [0.6918833356514636, 0.5878970108157671, -0.41...
# 7MBY  [-0.10244523265660867, -0.7827350495555255, -0...
#
#                                                     TM4  \
# 6OIJ  [-0.13006669814819627, -0.677979802596409, -0....
# 6WHA  [0.21136579817063456, 0.6773024269344856, 0.70...
# 7DFL  [-0.32101702541361793, -0.6223621521543671, 0....
# 7MBY  [-0.2722966218827753, 0.6077878575262717, 0.74...
#
#                                                     TM5  \
# 6OIJ  [-0.397210260547538, -0.20973640470943478, -0....
# 6WHA  [0.2771404014836226, -0.4282744332198132, -0.8...
# 7DFL  [-0.27182794030308816, -0.9377068162729052, 0....
# 7MBY  [0.25671250962603576, -0.8928721022796707, -0....
#
#                                                     TM6  \
# 6OIJ  [0.4749130325034923, 0.6028405615661779, 0.641...
# 6WHA  [0.30076466050272316, 0.4515458213624066, 0.84...
# 7DFL  [-0.034087831243284614, -0.7960196848743522, 0...
# 7MBY  [-0.5311678043819487, 0.6154189325917847, 0.58...
#
#                                                     TM7  \
# 6OIJ  [0.042821164053401875, 0.7069738414553997, 0.7...
# 6WHA  [-0.25408573194952333, -0.7896890531663878, -0...
# 7DFL  [0.2984568743613835, 0.5482141247215964, -0.78...
# 7MBY  [0.19630516999903022, -0.45232509831191714, -0...
#
#                                                      H8
# 6OIJ  [-0.5430946786023709, -0.37374798155384903, 0....
# 6WHA  [-0.8398632624064215, 0.5023069617973186, -0.2...
# 7DFL  [-0.8479232508841155, -0.5298019450774027, -0....
# 7MBY  [0.560207738907959, 0.7769530075333287, -0.287...

# %%
A.helices.loc['6WHA', ['TM6', 'TM7', 'H8']]
# Out:
# TM6    [0.30076466050272316, 0.4515458213624066, 0.84...
# TM7    [-0.25408573194952333, -0.7896890531663878, -0...
# H8     [-0.8398632624064215, 0.5023069617973186, -0.2...
# Name: 6WHA, dtype: object
